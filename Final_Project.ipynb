# %%
import pandas as pd
import json

# %%
pd.read_json('response_1593356838266.json', orient='records')
# Out:
#                           InstanceId             Name  OwnerId  \
# 0   950946fe358646498030139a7612afd2        Bayonetta        1
# 1   07dd592a2fe54a069e2ef22c80534143           Bowser        2
# 2   b637f5c4afce488a99b81adc9abf5e80         BowserJr        3
# 3   e96c62cf69144eaa8d02b03bd5fa7d43    CaptainFalcon        4
# 4   e1b71bcf5a6c4679a8a994168c4b6cc7        Charizard        5
# 5   7f73297b1deb488a9e6d0b53bfe1da30            Cloud        6
# 6   7f4a45c336e94115bd45066c782e0cb5           Corrin        7
# 7   89528474f71846d39850c9711343de36          DarkPit        8
# 8   7090c2265f0c4906817a6b5a98fd7761        DiddyKong        9
# 9   ada571c0d28d4b148502c06d38746ffa       DonkeyKong       10
# 10  36fc6d535da644ed9eb8f97daa24a800          DrMario       11
# 11  c2cba7ef4ba94f1aaea737a3f7e39f45         DuckHunt       12
# 12  e9e8c67059724d75bcacc72ae938bf16            Falco       13
# 13  486fd65cd11d4f3799612e3e1807e35a              Fox       14
# ...
