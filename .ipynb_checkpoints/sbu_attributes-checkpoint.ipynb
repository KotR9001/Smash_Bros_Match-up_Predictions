# %%
import pandas as pd
import requests
import json
import numpy as np

# %%
url_character = 'https://api.kuroganehammer.com/api/characters/?game=ultimate'
response = requests.get(url_character).json()

url_bayonetta = 'https://api.kuroganehammer.com/api/characters/name/bayonetta?game=ultimate'
response_bayonetta = requests.get(url_bayonetta).json()
response_bayonetta
# Out:
# {'Message': "Resource of type 'ICharacter' not found."}

# %%
char_df = pd.read_json(url_character)
print(len(char_df))
char_df.head()
# Out:
# 44
#                          InstanceId       Name  OwnerId  \
# 0  e7bacd54d4c04821a97798921eab4e21     Bowser        2
# 1  fbcc31bbd74e42a881084ae462ac77dc    DarkPit        8
# 2  d2ac2045f7d44ac9addba7fca92d54d9      Falco       13
# 3  14123762b7bd44a28b13289b9dda5191        Fox       14
# 4  4e3c55dd843e43f097bceeafd3f5c5a5  Ganondorf       15
#
#                                           FullUrl  \
# 0      https://kuroganehammer.com/Ultimate/Bowser
# 1  https://kuroganehammer.com/Ultimate/Dark%20Pit
# 2       https://kuroganehammer.com/Ultimate/Falco
# 3         https://kuroganehammer.com/Ultimate/Fox
# 4   https://kuroganehammer.com/Ultimate/Ganondorf
#
#                                         MainImageUrl  \
# 0  https://kuroganehammer.com/images/ultimate/log...
# 1  https://kuroganehammer.com/images/ultimate/log...
# 2  https://kuroganehammer.comhttp://kuroganehamme...
# 3  https://kuroganehammer.com/images/ultimate/log...
# 4  https://kuroganehammer.com/images/ultimate/log...
#
#                                         ThumbnailUrl ColorTheme DisplayName  \
# 0  https://kuroganehammer.com/images/ultimate/cha...    #32765C      Bowser
# 1  https://kuroganehammer.com/images/ultimate/cha...    #AF6CE9    Dark Pit
# 2  https://kuroganehammer.com/images/ultimate/cha...    #52B2E4       Falco
# 3  https://kuroganehammer.com/images/ultimate/cha...    #036AC9         Fox
# 4  https://kuroganehammer.com/images/ultimate/cha...    #7D7898   Ganondorf
#
#        Game                                            Related  \
# 0  Ultimate  {'Smash4': {'Self': 'http://api.kuroganehammer...
# 1  Ultimate  {'Smash4': {'Self': 'http://api.kuroganehammer...
# 2  Ultimate  {'Smash4': {'Self': 'http://api.kuroganehammer...
# 3  Ultimate  {'Smash4': {'Self': 'http://api.kuroganehammer...
# 4  Ultimate  {'Smash4': {'Self': 'http://api.kuroganehammer...
#
#                                                Links
# 0  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 1  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 2  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 3  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 4  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...

# %%
url_attributes = 'https://api.kuroganehammer.com/api/characterattributes/?game=ultimate'
attributes_df = pd.read_json(url_attributes)
print(len(attributes_df['Owner'].unique()))
attributes_df.head()
# Out:
# 39
#                          InstanceId             Name  OwnerId   Owner  \
# 0  f31da7259fc149b3a6dd2c426ba1c078  AirAcceleration        2  Bowser
# 1  32178c301783492e8e391ee49a540edb  AirAcceleration        2  Bowser
# 2  664dc216853646bb9f95279325c27647         AirSpeed        2  Bowser
# 3  e34b0537b51f46c9880ea594150b4a54         AirSpeed        2  Bowser
# 4  2f28dacf048444d6a4ffb2322b47daaa        FallSpeed        2  Bowser
#
#                                               Values      Game  \
# 0  [{'Value': '0.07', 'Owner': 'Bowser', 'OwnerId...  Ultimate
# 1  [{'Value': '0.04', 'Owner': 'Bowser', 'OwnerId...  Ultimate
# 2  [{'Value': '1.155', 'Owner': 'Bowser', 'OwnerI...  Ultimate
# 3  [{'Value': '1.134', 'Owner': 'Bowser', 'OwnerI...  Ultimate
# 4  [{'Value': '1.77', 'Owner': 'Bowser', 'OwnerId...  Ultimate
#
#                                              Related  \
# 0  {'Smash4': {'Character': 'http://api.kuroganeh...
# 1  {'Smash4': {'Character': 'http://api.kuroganeh...
# 2  {'Smash4': {'Character': 'http://api.kuroganeh...
# 3  {'Smash4': {'Character': 'http://api.kuroganeh...
# 4  {'Smash4': {'Character': 'http://api.kuroganeh...
#
#                                                Links
# 0  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 1  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 2  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 3  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 4  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...

# %%
url_moves = 'https://api.kuroganehammer.com/api/moves/?game=ultimate'
moves_df = pd.read_json(url_moves)
print(len(moves_df['Owner'].unique()))
moves_df.head()
# Out:
# 44
#                          InstanceId                Name  OwnerId   Owner  \
# 0  a1dba644ec1e403d9bb599ca5efe4b97               Jab 1        2  Bowser
# 1  916aeb8a38374683a01c0e8912368779               Jab 2        2  Bowser
# 2  10beeded0216414393f3fa1a46a9fab9         Dash Attack        2  Bowser
# 3  c3e269fcce174f9d86251025145831e3         Dash Attack        2  Bowser
# 4  a67c0d862538420596d2e28359c38951  Ftilt (All Angles)        2  Bowser
#
#   HitboxActive FirstActionableFrame BaseDamage            Angle  \
# 0          7-8                   26          4  361/361/180/361
# 1         9-11                   26          7              361
# 2        11-14                   56         12               80
# 3        15-20                    -         10               80
# 4        10-14                   38         13              361
#
#   BaseKnockBackSetKnockback LandingLag AutoCancel KnockbackGrowth MoveType  \
# 0               40/35/30/30       None       None              18   ground
# 1                        50       None       None             100   ground
# 2                       110       None       None              35   ground
# 3                        80       None       None              30   ground
# 4                        45       None       None              83   ground
#
#    IsWeightDependent      Game  \
# 0              False  Ultimate
# 1              False  Ultimate
# 2              False  Ultimate
# 3              False  Ultimate
# 4              False  Ultimate
#
#                                              Related  \
# 0  {'Smash4': {'Character': 'http://api.kuroganeh...
# 1  {'Smash4': {'Character': 'http://api.kuroganeh...
# 2  {'Smash4': {'Character': 'http://api.kuroganeh...
# 3  {'Smash4': {'Character': 'http://api.kuroganeh...
# 4  {'Smash4': {'Character': 'http://api.kuroganeh...
#
#                                                Links
# 0  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 1  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 2  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 3  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 4  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...

# %%
url_movement = 'https://api.kuroganehammer.com/api/movements/?game=ultimate'
movement_df = pd.read_json(url_movement)
print(len(movement_df['Owner'].unique()))
movement_df.head()
# Out:
# 44
#                          InstanceId        Name  OwnerId   Owner  Value  \
# 0  46c9455d7bb34b669822928bfd051df8      Weight        2  Bowser    135
# 1  4c89e2da3a0b4c8b889888994a856b56   Max Jumps        2  Bowser      2
# 2  506c767ce4684fcb8f0678ef66717478   Run Speed        2  Bowser  1.971
# 3  710da2b9a166492c8ddd07856fcd3f72   Wall Jump        2  Bowser     No
# 4  6d09d90138d84db88469b45d948e5b58  Walk Speed        2  Bowser  0.901
#
#        Game                                            Related  \
# 0  Ultimate  {'Smash4': {'Character': 'http://api.kuroganeh...
# 1  Ultimate  {'Smash4': {'Character': 'http://api.kuroganeh...
# 2  Ultimate  {'Smash4': {'Character': 'http://api.kuroganeh...
# 3  Ultimate  {'Smash4': {'Character': 'http://api.kuroganeh...
# 4  Ultimate  {'Smash4': {'Character': 'http://api.kuroganeh...
#
#                                                Links
# 0  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 1  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 2  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 3  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 4  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...

# %%
url_unique = 'https://api.kuroganehammer.com/api/uniqueproperties/?game=ultimate'
unique_df = pd.read_json(url_moves, orient = 'record')
print(len(unique_df['Owner'].unique()))
unique_df.head()
# Out:
# 44
#                          InstanceId                Name  OwnerId   Owner  \
# 0  a1dba644ec1e403d9bb599ca5efe4b97               Jab 1        2  Bowser
# 1  916aeb8a38374683a01c0e8912368779               Jab 2        2  Bowser
# 2  10beeded0216414393f3fa1a46a9fab9         Dash Attack        2  Bowser
# 3  c3e269fcce174f9d86251025145831e3         Dash Attack        2  Bowser
# 4  a67c0d862538420596d2e28359c38951  Ftilt (All Angles)        2  Bowser
#
#   HitboxActive FirstActionableFrame BaseDamage            Angle  \
# 0          7-8                   26          4  361/361/180/361
# 1         9-11                   26          7              361
# 2        11-14                   56         12               80
# 3        15-20                    -         10               80
# 4        10-14                   38         13              361
#
#   BaseKnockBackSetKnockback LandingLag AutoCancel KnockbackGrowth MoveType  \
# 0               40/35/30/30       None       None              18   ground
# 1                        50       None       None             100   ground
# 2                       110       None       None              35   ground
# 3                        80       None       None              30   ground
# 4                        45       None       None              83   ground
#
#    IsWeightDependent      Game  \
# 0              False  Ultimate
# 1              False  Ultimate
# 2              False  Ultimate
# 3              False  Ultimate
# 4              False  Ultimate
#
#                                              Related  \
# 0  {'Smash4': {'Character': 'http://api.kuroganeh...
# 1  {'Smash4': {'Character': 'http://api.kuroganeh...
# 2  {'Smash4': {'Character': 'http://api.kuroganeh...
# 3  {'Smash4': {'Character': 'http://api.kuroganeh...
# 4  {'Smash4': {'Character': 'http://api.kuroganeh...
#
#                                                Links
# 0  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 1  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 2  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 3  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...
# 4  [{'Rel': 'self', 'Href': 'http://api.kuroganeh...

# %%
new_df = unique_df.T
new_df.head()
# Out:
#                                           0     \
# InstanceId    a1dba644ec1e403d9bb599ca5efe4b97
# Name                                     Jab 1
# OwnerId                                      2
# Owner                                   Bowser
# HitboxActive                               7-8
#
#                                           1     \
# InstanceId    916aeb8a38374683a01c0e8912368779
# Name                                     Jab 2
# OwnerId                                      2
# Owner                                   Bowser
# HitboxActive                              9-11
#
#                                           2     \
# InstanceId    10beeded0216414393f3fa1a46a9fab9
# Name                               Dash Attack
# OwnerId                                      2
# Owner                                   Bowser
# HitboxActive                             11-14
#
#                                           3     \
# InstanceId    c3e269fcce174f9d86251025145831e3
# Name                               Dash Attack
# OwnerId                                      2
# Owner                                   Bowser
# HitboxActive                             15-20
#
#                                           4     \
# InstanceId    a67c0d862538420596d2e28359c38951
# Name                        Ftilt (All Angles)
# OwnerId                                      2
# Owner                                   Bowser
# HitboxActive                             10-14
#
#                                           5     \
# InstanceId    03cf7f6b06804f78a328014c018ac84c
# Name                                     Utilt
# OwnerId                                      2
# Owner                                   Bowser
# HitboxActive                             11-16
#
#                                           6     \
# InstanceId    379ced4a259c4614bf3cdee20af0dcfe
# Name                             Dtilt (Hit 1)
# OwnerId                                      2
# Owner                                   Bowser
# HitboxActive                             10-12
#
#                                           7     \
# InstanceId    226a0e7b458e4402bc7baee5201596eb
# Name                             Dtilt (Hit 2)
# OwnerId                                      2
# Owner                                   Bowser
# HitboxActive                             15-17
#
#                                           8     \
# InstanceId    431476f97a9a49e9b71deb9b17f0aa9b
# Name                                    Fsmash
# OwnerId                                      2
# Owner                                   Bowser
# HitboxActive                             22-23
#
#                                           9     ...  \
# InstanceId    9c8387a48e1d48f48a7feec2a6eba032  ...
# Name                             Fsmash (Late)  ...
# OwnerId                                      2  ...
# Owner                                   Bowser  ...
# HitboxActive                             24-27  ...
#
#                                           2575  \
# InstanceId    46dedc088b1c4e488c7aa3ce69a17286
# Name               Spin Attack (Hit 6, Aerial)
# OwnerId                                     79
# Owner                                YoungLink
# HitboxActive                             26-27
#
#                                           2576  \
# InstanceId    205fdf79181c450e838f54a70ffcceab
# Name               Spin Attack (Hit 7, Aerial)
# OwnerId                                     79
# Owner                                YoungLink
# HitboxActive                             31-33
#
#                                           2577  \
# InstanceId    7da7193ba7d34d04936562b3e045347a
# Name               Spin Attack (Hit 8, Aerial)
# OwnerId                                     79
# Owner                                YoungLink
# HitboxActive                             39-40
#
#                                           2578  \
# InstanceId    5f692b8929ee42e793e7d91c8e8e22d8
# Name               Spin Attack (Hit 9, Aerial)
# OwnerId                                     79
# Owner                                YoungLink
# HitboxActive                             47-51
#
#                                           2579  \
# InstanceId    1b6fd59b4ecc4265b933541cd374cab7
# Name                               Bomb (Pull)
# OwnerId                                     79
# Owner                                YoungLink
# HitboxActive                     Generated: 17
#
#                                           2580  \
# InstanceId    f3095246d1354e658d0e9623963ebf5a
# Name                          Bomb (Explosion)
# OwnerId                                     79
# Owner                                YoungLink
# HitboxActive                        1, 3, 5, 7
#
#                                           2581  \
# InstanceId    b5eb91f1f2e645728bc3f73f44091ca8
# Name                                    Fthrow
# OwnerId                                     79
# Owner                                YoungLink
# HitboxActive                              None
#
#                                           2582  \
# InstanceId    39c55d4d51164fb682c0aa251a1945dd
# Name                                    Bthrow
# OwnerId                                     79
# Owner                                YoungLink
# HitboxActive                              None
#
#                                           2583  \
# InstanceId    654da1980afc48eab09ca82175ea60be
# Name                                    Uthrow
# OwnerId                                     79
# Owner                                YoungLink
# HitboxActive                              None
#
#                                           2584
# InstanceId    82d21cfed435419a9f93d937d3e83912
# Name                                    Dthrow
# OwnerId                                     79
# Owner                                YoungLink
# HitboxActive                              None
#
# [5 rows x 2585 columns]

# %%
#Create Pivot Table without Aggregation
#Method Found at https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pivot.html


#Create a Copy of the Table for Operations
moves1 = moves_df.copy()

#Split the Values for Hitbox Active and Use the First Value
moves1['HitboxActive'] =moves1['HitboxActive'].astype(str)
moves1['HitboxActive'] = moves1['HitboxActive'].str.split(pat="-")
moves1['HitboxActive'] = moves1['HitboxActive'].map(lambda x: x[0])
#Method to Convert Elements Containing Strings Back to Numeric Data Found at https://stackoverflow.com/questions/42719749/pandas-convert-string-to-int
moves1['HitboxActive'] = pd.to_numeric(moves1['HitboxActive'], errors='coerce')
print(moves1['HitboxActive'])

#Create the Pivot Table
hitbox_pivot = moves1.pivot_table(index='Owner', columns='Name', aggfunc=np.mean, values='HitboxActive')
hitbox_pivot = hitbox_pivot[['Airdodge', 'Bair', 'Dair', 'Dash Attack', 'Dash Grab', 'Dsmash', 
                            'Dtilt', 'Fair', 'Fsmash', 'Ftilt', 'Jab 1', 'Jab 2', 'Jab 3','Light Utilt',
                            'Medium Dtilt', 'Medium Jab 1', 
                            'Nair', 'Spotdodge', 'Standing Grab', 'Uair', 'Usmash', 'Utilt']]
hitbox_pivot
# Out:
# 0        7.0
# 1        9.0
# 2       11.0
# 3       15.0
# 4       10.0
#         ...
# 2580     NaN
# 2581     NaN
# 2582     NaN
# 2583     NaN
# 2584     NaN
# Name: HitboxActive, Length: 2585, dtype: float64
# Name          Airdodge  Bair  Dair  Dash Attack  Dash Grab  Dsmash  Dtilt  \
# Owner
# BanjoKazooie       3.0   NaN  15.0          9.0       10.0    13.0   12.0
# Bowser             4.0   9.0  17.0         13.0       11.0     NaN    NaN
# Chrom              3.0   8.0  16.0         13.0        8.0     NaN    7.0
# Daisy              NaN   6.0   NaN          NaN        9.0     NaN    8.0
# DarkPit            NaN  10.0  10.0          7.0        9.0     NaN    6.0
# Falco              2.0   9.0  10.0          8.0        9.0     8.0   10.0
# Fox                NaN   9.0   NaN          4.0       10.0     6.0    7.0
# Ganondorf          4.0  10.0  16.0         10.0       11.0     NaN   10.0
# Greninja           2.0   NaN  17.0          7.0       13.0    11.0    5.0
# Hero               3.0  18.0  16.0         21.0        9.0     NaN    6.0
# IceClimbers        3.0   8.0  12.0         11.0       10.0     9.0    8.0
# Ike                NaN   7.0  16.0         15.0       10.0     NaN    7.0
# Incineroar         3.0   7.0  16.0          8.0       12.0    18.0    9.0
# Inkling            NaN   7.0  16.0          9.0        9.0     NaN    NaN
# Ivysaur            3.0   NaN  11.0          4.0       13.0    13.0    4.0
# Joker              NaN   7.0  13.0          NaN        8.0     NaN   10.0
# Ken                3.0   8.0   8.0          7.0        9.0     5.0    NaN
# KingKRool          4.0  18.0  14.0          7.0       11.0    22.0   13.0
# Kirby              3.0   6.0   NaN         18.0        9.0    10.0    4.0
# LittleMac          2.0  11.0   7.0          7.0       13.0     NaN    3.0
# Lucina             3.0   7.0  11.0         13.0        9.0     NaN    7.0
# Marth              3.0   7.0  11.0         13.0        9.0     NaN    7.0
# MetaKnight         2.0   NaN   4.0          7.0       11.0     NaN    3.0
# Mewtwo             3.0  13.0  15.0         10.0       10.0    21.0    6.0
# Palutena           3.0   8.0  10.0          6.0       10.0    17.0   14.0
# Peach              NaN   6.0   NaN          NaN        9.0     NaN    8.0
# Pichu              NaN   NaN  14.0          6.0        8.0     NaN    7.0
# PiranhaPlant       3.0  14.0   9.0          7.0        9.0     NaN    9.0
# Pit                NaN  10.0  10.0          7.0        9.0     NaN    6.0
# Richter            NaN  14.0  13.0         10.0       13.0     NaN    NaN
# Ridley             3.0  10.0  11.0         12.0       11.0    24.0    9.0
# Rob                3.0  19.0  20.0          7.0        9.0     NaN    3.0
# RosalinaLuma       3.0   9.0  21.0          NaN        9.0     NaN    5.0
# Roy                NaN   8.0  16.0         13.0        8.0     NaN    7.0
# Ryu                3.0   8.0   8.0          7.0        9.0     5.0    NaN
# Shulk              3.0  19.0   NaN         12.0       10.0     NaN   10.0
# Simon              NaN  14.0  13.0         10.0       13.0     NaN    NaN
# Snake              NaN   7.0   NaN          5.0       11.0     NaN    6.0
# Squirtle           NaN   5.0   6.0          8.0        8.0     NaN    8.0
# Terry              3.0  11.0  12.0         10.0        9.0     8.0    6.0
# Wario              NaN   9.0   NaN          5.0       11.0     NaN    5.0
# Wolf               NaN  13.0  16.0         11.0        8.0     NaN    5.0
# YoungLink          2.0   NaN  13.0          8.0       14.0     NaN    8.0
# Zelda              3.0   6.0  14.0          6.0       13.0     NaN    5.0
#
# Name               Fair  Fsmash  Ftilt  ...  Jab 3  Light Utilt  Medium Dtilt  \
# Owner                                   ...
# BanjoKazooie  15.000000    19.0    NaN  ...    5.0          NaN           NaN
# Bowser        11.000000    22.0    NaN  ...    NaN          NaN           NaN
# Chrom         10.000000    13.0    8.0  ...    NaN          NaN           NaN
# Daisy         16.000000    15.0    8.0  ...    NaN          NaN           NaN
# DarkPit             NaN     NaN   10.0  ...    3.0          NaN           NaN
# Falco          7.000000    17.0    NaN  ...    NaN          NaN           NaN
# Fox                 NaN    13.0    6.0  ...    NaN          NaN           NaN
# Ganondorf     14.000000    29.0   10.0  ...    NaN          NaN           NaN
# Greninja      16.000000    13.0   10.0  ...    5.0          NaN           NaN
# Hero          14.000000    17.0    NaN  ...    7.0          NaN           NaN
# IceClimbers   19.000000    11.0    NaN  ...    NaN          NaN           NaN
# Ike           11.000000    31.0    NaN  ...    5.0          NaN           NaN
# Incineroar     8.000000    16.0    NaN  ...    4.0          NaN           NaN
# Inkling       10.000000    16.0    8.0  ...    4.0          NaN           NaN
# Ivysaur       14.000000    15.0    NaN  ...    NaN          NaN           NaN
# Joker               NaN    16.0    NaN  ...    3.0          NaN           NaN
# Ken            8.000000    13.0    NaN  ...    8.0          4.0           6.0
# KingKRool     12.000000    19.0    NaN  ...    5.0          NaN           NaN
# Kirby               NaN     NaN    NaN  ...    NaN          NaN           NaN
# LittleMac     10.000000    14.0    NaN  ...    4.0          NaN           NaN
# Lucina         6.000000    10.0    8.0  ...    NaN          NaN           NaN
# Marth          6.000000    10.0    8.0  ...    NaN          NaN           NaN
# MetaKnight          NaN    24.0    NaN  ...    NaN          NaN           NaN
# Mewtwo         7.000000     NaN    NaN  ...    NaN          NaN           NaN
# Palutena       9.000000    18.0    NaN  ...    NaN          NaN           NaN
# Peach         16.000000    15.0    8.0  ...    NaN          NaN           NaN
# Pichu               NaN     NaN    5.0  ...    NaN          NaN           NaN
# PiranhaPlant  10.000000    16.0    NaN  ...    7.0          NaN           NaN
# Pit                 NaN     NaN   10.0  ...    3.0          NaN           NaN
# Richter       14.000000    24.0   12.0  ...    NaN          NaN           NaN
# Ridley              NaN    18.0   10.0  ...    4.0          NaN           NaN
# Rob            6.000000     NaN    NaN  ...    NaN          NaN           NaN
# RosalinaLuma  13.333333     NaN    7.0  ...    7.0          NaN           NaN
# Roy           10.000000    13.0    8.0  ...    NaN          NaN           NaN
# Ryu            8.000000    15.0    NaN  ...    8.0          4.0           6.0
# Shulk         14.000000     NaN   12.0  ...    6.0          NaN           NaN
# Simon         14.000000    24.0   12.0  ...    NaN          NaN           NaN
# Snake         23.000000    41.0    NaN  ...    8.0          NaN           NaN
# Squirtle       5.000000    20.0    5.0  ...    5.0          NaN           NaN
# Terry          7.000000    18.0    8.0  ...    7.0          NaN           NaN
# Wario          5.000000    18.0    NaN  ...    NaN          NaN           NaN
# Wolf           7.000000    20.0    NaN  ...    4.0          NaN           NaN
# YoungLink           NaN     NaN   10.0  ...    6.0          NaN           NaN
# Zelda          6.000000     NaN    NaN  ...    NaN          NaN           NaN
#
# Name          Medium Jab 1  Nair  Spotdodge  Standing Grab  Uair  Usmash  \
# Owner
# BanjoKazooie           NaN   NaN        3.0            7.0   NaN    13.0
# Bowser                 NaN   NaN        3.0            8.0   9.0    16.0
# Chrom                  NaN   NaN        3.0            7.0   5.0     NaN
# Daisy                  NaN   5.0        NaN            6.0   NaN    14.0
# DarkPit                NaN   NaN        NaN            6.0   NaN     NaN
# Falco                  NaN   NaN        3.0            6.0   7.0     NaN
# Fox                    NaN   4.0        NaN            6.0   NaN     8.0
# Ganondorf              NaN   NaN        3.0            8.0  11.0    20.0
# Greninja               NaN  12.0        3.0           10.0   NaN     NaN
# Hero                   NaN   8.0        3.0            6.0   6.0    13.0
# IceClimbers            NaN   6.0        3.0            8.0   7.0    12.0
# Ike                    NaN  10.0        NaN            7.0  13.0    25.0
# Incineroar             NaN   5.0        3.0            8.0   7.0    13.0
# Inkling                NaN   6.0        NaN            8.0   NaN     NaN
# Ivysaur                NaN   7.0        3.0           13.0  12.0    26.0
# Joker                  NaN  12.0        NaN            6.0   5.0    10.0
# Ken                    7.0   6.0        3.0            6.0   5.0     9.0
# KingKRool              NaN   7.0        3.0            8.0   7.0     NaN
# Kirby                  NaN  12.0        3.0            6.0  10.0    15.0
# LittleMac              NaN   2.0        3.0            9.0   5.0    10.0
# Lucina                 NaN   NaN        3.0            6.0   5.0    13.0
# Marth                  NaN   NaN        3.0            6.0   5.0    13.0
# MetaKnight             NaN   6.0        3.0            7.0   6.0     NaN
# Mewtwo                 NaN   NaN        3.0            7.0  10.0     NaN
# Palutena               NaN   5.0        3.0            7.0  10.0    18.0
# Peach                  NaN   5.0        NaN            6.0   NaN    14.0
# Pichu                  NaN   3.0        NaN            6.0   4.0     9.0
# PiranhaPlant           NaN   8.0        3.0            6.0   7.0     NaN
# Pit                    NaN   NaN        NaN            6.0   NaN     NaN
# Richter                NaN   8.0        NaN           10.0  14.0    18.0
# Ridley                 NaN   8.0        3.0            8.0  11.0    12.0
# Rob                    NaN  14.0        3.0            6.0   NaN    14.0
# RosalinaLuma           NaN   9.0        3.0            6.0  11.0     8.0
# Roy                    NaN   NaN        NaN            7.0   5.0     NaN
# Ryu                    7.0   4.0        3.0            6.0   NaN     9.0
# Shulk                  NaN  13.0        3.0            7.0   NaN     NaN
# Simon                  NaN   8.0        NaN           10.0  14.0    18.0
# Snake                  NaN   NaN        NaN            8.0  10.0     NaN
# Squirtle               NaN   4.0        NaN            6.0   5.0    23.0
# Terry                  NaN   4.0        3.0            6.0   7.0    10.0
# Wario                  NaN   NaN        NaN            8.0   8.0    11.0
# Wolf                   NaN   7.0        NaN            6.0   7.0     NaN
# YoungLink              NaN   4.0        3.0           12.0   5.0     NaN
# Zelda                  NaN   NaN        3.0           10.0  14.0    17.0
#
# Name          Utilt
# Owner
# BanjoKazooie   11.0
# Bowser         11.0
# Chrom           6.0
# Daisy           9.0
# DarkPit         NaN
# Falco           NaN
# Fox             3.0
# Ganondorf      60.0
# Greninja        9.0
# Hero            8.0
# IceClimbers     NaN
# Ike            11.0
# Incineroar      6.0
# Inkling         7.0
# Ivysaur         7.0
# Joker          10.0
# Ken             NaN
# KingKRool       5.0
# Kirby           4.0
# LittleMac       4.0
# Lucina          6.0
# Marth           7.0
# MetaKnight      8.0
# Mewtwo          8.0
# Palutena        8.0
# Peach           9.0
# Pichu           7.0
# PiranhaPlant    8.0
# Pit             NaN
# Richter        10.0
# Ridley          8.0
# Rob             NaN
# RosalinaLuma    7.0
# Roy             7.0
# Ryu             NaN
# Shulk          11.0
# Simon          10.0
# Snake           6.0
# Squirtle        5.0
# Terry           7.0
# Wario           8.0
# Wolf            7.0
# YoungLink       9.0
# Zelda           7.0
#
# [44 rows x 22 columns]

# %%
#Split the Values for First Actionable Frame and Use the First Value
moves1['FirstActionableFrame'] =moves1['FirstActionableFrame'].astype(str)
moves1['FirstActionableFrame'] = moves1['FirstActionableFrame'].str.split(pat="-")
#Method to Take the First Element from Each Row Found at https://www.w3schools.com/python/python_lambda.asp
moves1['FirstActionableFrame'] = moves1['FirstActionableFrame'].map(lambda x: x[0])
#Method to Convert Elements Containing Strings Back to Numeric Data Found at https://stackoverflow.com/questions/42719749/pandas-convert-string-to-int
moves1['FirstActionableFrame'] = pd.to_numeric(moves1['FirstActionableFrame'], errors='coerce')
#print(moves1['FirstActionableFrame'])

#Create the Pivot Table
faf_pivot = moves1.pivot_table(index='Owner', columns='Name', aggfunc=np.mean, values='FirstActionableFrame')
faf_pivot = faf_pivot[['Airdodge', 'Bair', 'Dair', 'Dash Attack', 'Dash Grab', 'Dsmash', 
                            'Dtilt', 'Fair', 'Fsmash', 'Ftilt', 'Jab 1', 'Jab 2', 'Jab 3','Light Utilt',
                            'Medium Dtilt', 'Medium Jab 1', 'Medium Utilt',
                            'Nair', 'Spotdodge', 'Standing Grab', 'Uair', 'Usmash', 'Utilt']]
faf_pivot
# Out:
# Name          Airdodge  Bair  Dair  Dash Attack  Dash Grab  Dsmash  Dtilt  \
# Owner
# BanjoKazooie      46.0   NaN  57.0         37.0       45.0    47.0   38.0
# Bowser            47.0  45.0  78.0         56.0       49.0     NaN    NaN
# Chrom             45.0  36.0  52.0         46.0       45.0     NaN   22.0
# Daisy              NaN  54.0   NaN          NaN       45.0     NaN   24.0
# DarkPit            NaN  41.0  37.0         39.0       43.0     NaN   26.0
# Falco             44.0  38.0  52.0         39.0       42.0    47.0   32.0
# Fox                NaN  49.0   NaN         32.0       46.0    53.0   28.0
# Ganondorf         47.0  36.0  45.0         38.0       47.0     NaN   36.0
# Greninja          42.0   NaN   NaN         29.0       47.0    50.0   23.0
# Hero              51.0  48.0  63.0         52.0       43.0     NaN   33.0
# IceClimbers       59.0  36.0  64.0         42.0       48.0    41.0   31.0
# Ike                NaN  55.0  55.0         48.0       45.0     NaN   29.0
# Incineroar        45.0  42.0  45.0         42.0       47.0    58.0   30.0
# Inkling            NaN  37.0  62.0         36.0       42.0     NaN    NaN
# Ivysaur           57.0   NaN  64.0         44.0       49.0    46.0   31.0
# Joker              NaN  32.0  47.0          NaN       43.0     NaN    NaN
# Ken               50.0  42.0  46.0         41.0       43.0    42.0    NaN
# KingKRool         47.0  60.0  62.0         61.0       49.0    64.0   43.0
# Kirby             63.0  41.0   NaN          NaN       42.0    54.0   21.0
# LittleMac         50.0  38.0  28.0          NaN       47.0     NaN   26.0
# Lucina            53.0  40.0   NaN         50.0       43.0     NaN   24.0
# Marth             53.0  40.0   NaN         50.0       43.0     NaN   24.0
# MetaKnight        48.0   NaN  28.0         33.0       45.0     NaN   19.0
# Mewtwo            52.0  40.0  48.0         39.0       48.0    41.0   24.0
# Palutena          50.0  50.0  59.0         38.0       48.0    69.0   40.0
# Peach              NaN  54.0   NaN          NaN       45.0     NaN   24.0
# Pichu              NaN   NaN  48.0         35.0       40.0     NaN   19.0
# PiranhaPlant      43.0  62.0  45.0         48.0       43.0     NaN   29.0
# Pit                NaN  41.0  37.0         39.0       43.0     NaN   26.0
# Richter            NaN  40.0  49.0         55.0       46.0     NaN    NaN
# Ridley            47.0  44.0  56.0         40.0       43.0    58.0   31.0
# Rob               51.0   NaN  70.0         32.0       46.0     NaN   15.0
# RosalinaLuma      63.0  55.0  50.0          NaN       47.0     NaN   33.0
# Roy                NaN  36.0  52.0         46.0       45.0     NaN   22.0
# Ryu               50.0  42.0  46.0         41.0       43.0    42.0    NaN
# Shulk             50.0  55.0   NaN         41.0       45.0     NaN   32.0
# Simon              NaN  40.0  49.0         55.0       46.0     NaN    NaN
# Snake              NaN  43.0   NaN         42.0       43.0     NaN   31.0
# Squirtle           NaN  36.0  45.0         36.0       40.0     NaN   30.0
# Terry             52.0   NaN   NaN         41.0       43.0    41.0   17.0
# Wario              NaN  50.0   NaN         49.0       44.0    62.0   18.0
# Wolf               NaN  45.0  54.0         38.0       45.0     NaN   28.0
# YoungLink         46.0   NaN  80.0         35.0       61.0     NaN   26.0
# Zelda             57.0  50.0  45.0         36.0       48.0     NaN   22.0
#
# Name          Fair  Fsmash  Ftilt  ...  Light Utilt  Medium Dtilt  \
# Owner                              ...
# BanjoKazooie  52.0    53.0    NaN  ...          NaN           NaN
# Bowser        42.0    70.0    NaN  ...          NaN           NaN
# Chrom         30.0    54.0   34.0  ...          NaN           NaN
# Daisy         58.0    46.0    NaN  ...          NaN           NaN
# DarkPit        NaN     NaN   40.0  ...          NaN           NaN
# Falco         50.0    49.0    NaN  ...          NaN           NaN
# Fox            NaN    46.0    NaN  ...          NaN           NaN
# Ganondorf     45.0    70.0   40.0  ...          NaN           NaN
# Greninja      55.0    50.0    NaN  ...          NaN           NaN
# Hero          43.0    66.0    NaN  ...          NaN           NaN
# IceClimbers   57.0    47.0    NaN  ...          NaN           NaN
# Ike           60.0    84.0    NaN  ...          NaN           NaN
# Incineroar    45.0    54.0    NaN  ...          NaN           NaN
# Inkling       42.0    52.0   35.0  ...          NaN           NaN
# Ivysaur       49.0    60.0    NaN  ...          NaN           NaN
# Joker          NaN    48.0    NaN  ...          NaN           NaN
# Ken           37.0    46.0    NaN  ...         16.0          28.0
# KingKRool      NaN    62.0    NaN  ...          NaN           NaN
# Kirby          NaN     NaN    NaN  ...          NaN           NaN
# LittleMac     37.0    44.0    NaN  ...          NaN           NaN
# Lucina        38.0    52.0   34.0  ...          NaN           NaN
# Marth         38.0    52.0   34.0  ...          NaN           NaN
# MetaKnight     NaN    42.0    NaN  ...          NaN           NaN
# Mewtwo        40.0     NaN    NaN  ...          NaN           NaN
# Palutena      45.0    64.0    NaN  ...          NaN           NaN
# Peach         58.0    46.0    NaN  ...          NaN           NaN
# Pichu          NaN     NaN   25.0  ...          NaN           NaN
# PiranhaPlant  48.0    52.0    NaN  ...          NaN           NaN
# Pit            NaN     NaN   40.0  ...          NaN           NaN
# Richter       40.0    63.0   31.0  ...          NaN           NaN
# Ridley         NaN    54.0   33.0  ...          NaN           NaN
# Rob           36.0     NaN    NaN  ...          NaN           NaN
# RosalinaLuma  55.0     NaN   38.0  ...          NaN           NaN
# Roy           30.0    54.0   34.0  ...          NaN           NaN
# Ryu           37.0    46.0    NaN  ...         16.0          28.0
# Shulk         42.0     NaN   44.0  ...          NaN           NaN
# Simon         40.0    63.0   31.0  ...          NaN           NaN
# Snake         70.0    74.0    NaN  ...          NaN           NaN
# Squirtle      36.0    50.0   18.0  ...          NaN           NaN
# Terry          NaN    51.0   28.0  ...          NaN           NaN
# Wario         38.0    66.0    NaN  ...          NaN           NaN
# Wolf          41.0    42.0    NaN  ...          NaN           NaN
# YoungLink      NaN     NaN   34.0  ...          NaN           NaN
# Zelda         50.0     NaN    NaN  ...          NaN           NaN
#
# Name          Medium Jab 1  Medium Utilt  Nair  Spotdodge  Standing Grab  \
# Owner
# BanjoKazooie           NaN           NaN   NaN       26.0           37.0
# Bowser                 NaN           NaN   NaN       29.0           41.0
# Chrom                  NaN           NaN   NaN       26.0           37.0
# Daisy                  NaN           NaN  49.0        NaN           37.0
# DarkPit                NaN           NaN   NaN        NaN           35.0
# Falco                  NaN           NaN   NaN       26.0           34.0
# Fox                    NaN           NaN  42.0        NaN           38.0
# Ganondorf              NaN           NaN   NaN        NaN           39.0
# Greninja               NaN           NaN  53.0       25.0           39.0
# Hero                   NaN           NaN  46.0       26.0           35.0
# IceClimbers            NaN           NaN  46.0       26.0           40.0
# Ike                    NaN           NaN  60.0        NaN           37.0
# Incineroar             NaN           NaN  42.0       27.0           39.0
# Inkling                NaN           NaN  32.0        NaN           35.0
# Ivysaur                NaN           NaN  42.0       27.0           43.0
# Joker                  NaN           NaN  55.0        NaN           35.0
# Ken                   38.0          38.0  28.0       27.0           35.0
# KingKRool              NaN           NaN  46.0       29.0           41.0
# Kirby                  NaN           NaN   NaN       27.0           34.0
# LittleMac              NaN           NaN  16.0       24.0           39.0
# Lucina                 NaN           NaN   NaN       26.0           35.0
# Marth                  NaN           NaN   NaN       26.0           35.0
# MetaKnight             NaN           NaN  44.0       25.0           37.0
# Mewtwo                 NaN           NaN   NaN       26.0           40.0
# Palutena               NaN           NaN  52.0       26.0           40.0
# Peach                  NaN           NaN  49.0        NaN           37.0
# Pichu                  NaN           NaN  40.0        NaN           32.0
# PiranhaPlant           NaN           NaN  48.0       26.0           35.0
# Pit                    NaN           NaN   NaN        NaN           35.0
# Richter                NaN           NaN  43.0        NaN           38.0
# Ridley                 NaN           NaN  40.0       29.0           35.0
# Rob                    NaN           NaN  48.0       26.0           38.0
# RosalinaLuma           NaN           NaN  44.0       27.0           40.0
# Roy                    NaN           NaN   NaN        NaN           37.0
# Ryu                   38.0          38.0  36.0       27.0           35.0
# Shulk                  NaN           NaN  60.0       25.0           37.0
# Simon                  NaN           NaN  43.0        NaN           38.0
# Snake                  NaN           NaN   NaN        NaN           35.0
# Squirtle               NaN           NaN  42.0        NaN           35.0
# Terry                  NaN           NaN   NaN       26.0           35.0
# Wario                  NaN           NaN   NaN        NaN           36.0
# Wolf                   NaN           NaN  43.0        NaN           37.0
# YoungLink              NaN           NaN  36.0       25.0           53.0
# Zelda                  NaN           NaN   NaN       27.0           40.0
#
# Name          Uair  Usmash  Utilt
# Owner
# BanjoKazooie   NaN     NaN   32.0
# Bowser        45.0    58.0   41.0
# Chrom         42.0     NaN   39.0
# Daisy          NaN    45.0   38.0
# DarkPit        NaN     NaN    NaN
# Falco         34.0     NaN    NaN
# Fox            NaN    56.0   28.0
# Ganondorf      NaN    62.0    NaN
# Greninja       NaN     NaN   33.0
# Hero          33.0    54.0   42.0
# IceClimbers   36.0    50.0    NaN
# Ike           57.0    71.0   40.0
# Incineroar    32.0    48.0   35.0
# Inkling        NaN     NaN   30.0
# Ivysaur       52.0    60.0   33.0
# Joker         40.0    52.0    NaN
# Ken           36.0    45.0    NaN
# KingKRool     82.0     NaN   38.0
# Kirby         38.0     NaN   21.0
# LittleMac     42.0    48.0   30.0
# Lucina        46.0     NaN   34.0
# Marth         46.0     NaN    NaN
# MetaKnight    27.0     NaN   35.0
# Mewtwo        40.0     NaN   30.0
# Palutena      52.0    64.0   56.0
# Peach          NaN    45.0   38.0
# Pichu         27.0    41.0   24.0
# PiranhaPlant  39.0     NaN   32.0
# Pit            NaN     NaN    NaN
# Richter       40.0    56.0   38.0
# Ridley        40.0    48.0   30.0
# Rob            NaN     NaN    NaN
# RosalinaLuma   NaN    48.0   41.0
# Roy           42.0     NaN    NaN
# Ryu            NaN    45.0    NaN
# Shulk          NaN     NaN   40.0
# Simon         40.0    56.0   38.0
# Snake         48.0     NaN   38.0
# Squirtle      30.0     NaN   20.0
# Terry          NaN    42.0   31.0
# Wario         47.0    58.0   28.0
# Wolf          39.0     NaN   36.0
# YoungLink     60.0     NaN   32.0
# Zelda         55.0    64.0   30.0
#
# [44 rows x 23 columns]

# %%
#Split the Values for Base Damage and Use the First Value
moves1['BaseDamage'] = moves1['BaseDamage'].astype(str)
moves1['BaseDamage'] = moves1['BaseDamage'].str.split(pat="/")
moves1['BaseDamage'] = moves1['BaseDamage'].map(lambda x: x[0])
#Method to Convert Elements Containing Strings Back to Numeric Data Found at https://stackoverflow.com/questions/42719749/pandas-convert-string-to-int
moves1['BaseDamage'] = pd.to_numeric(moves1['BaseDamage'], errors='coerce')
#print(moves1['BaseDamage'])

#Create the Pivot Table
damage_pivot = moves1.pivot_table(index='Owner', columns='Name', aggfunc=np.mean, values='BaseDamage')
damage_pivot = damage_pivot[['Bair', 'Bthrow', 'Dair', 'Dash Attack', 'Dsmash', 'Dthrow',
                            'Dtilt', 'Fair', 'Fsmash', 'Fthrow', 'Ftilt', 'Jab 1', 'Jab 2', 'Jab 3','Light Utilt',
                            'Medium Dtilt', 'Medium Jab 1', 'Medium Utilt',
                            'Nair', 'Rapid Jab', 'Uair', 'Usmash', 'Uthrow', 'Utilt']]
damage_pivot
# Out:
# Name            Bair  Bthrow   Dair  Dash Attack  Dsmash  Dthrow  Dtilt  \
# Owner
# BanjoKazooie     NaN    11.4  10.00       12.000    15.0     5.6    5.0
# Bowser        19.000    12.0  16.00       11.000     NaN     NaN    NaN
# Chrom         10.925     5.0  14.25       12.000     NaN     5.0    9.0
# Daisy         12.000     NaN    NaN          NaN     NaN     NaN    7.0
# DarkPit       12.000     8.0  10.00       11.000     NaN     NaN    6.0
# Falco         13.000     6.0  13.00        9.000    15.0     3.0   13.0
# Fox           13.000     NaN    NaN        6.000    14.0     NaN    8.0
# Ganondorf     17.000     NaN  19.00       15.000     NaN     7.0   14.0
# Greninja         NaN     9.0   8.00        8.000    13.0     5.0    4.0
# Hero          12.000     9.0  16.00       13.000     NaN     6.0    7.0
# IceClimbers   10.000     6.0   8.00        6.000    13.0     6.0    6.0
# Ike           14.000     NaN  15.00       14.000     NaN     NaN    8.0
# Incineroar    11.000     NaN  14.00       13.000    16.0     9.0    9.0
# Ivysaur          NaN    12.0  10.00       12.000     8.0     7.0    5.5
# Joker          9.000    10.0   8.00          NaN     NaN     7.0    6.0
# Ken           16.000    12.0  15.00       12.000    16.0     NaN    NaN
# KingKRool     14.500    11.0  12.00       15.000    18.0     5.0   13.0
# Kirby         13.000     8.0    NaN        9.000    15.0     NaN    6.0
# LittleMac      6.000     NaN   5.00       10.000     NaN     NaN    8.0
# Lucina        11.875     4.0  14.25       10.925     NaN     4.0    8.5
# Marth          9.000     4.0  15.00       10.000     NaN     4.0    7.0
# MetaKnight       NaN     NaN   6.00        7.000     NaN     NaN    5.0
# Mewtwo        13.000    11.0  15.00       12.000    16.0     NaN    5.0
# Palutena      12.000    10.0  11.00       11.000    15.0     5.0    8.5
# Peach         12.000     NaN    NaN          NaN     NaN     NaN    7.0
# PiranhaPlant  14.500    11.0  11.00       10.000     NaN     NaN    6.0
# Pit           12.000     8.0  10.00       11.000     NaN     NaN    6.0
# Ridley        15.000    11.0  14.00       12.000    16.0     7.0    6.0
# Rob           15.000    10.0  12.00        7.000     NaN     5.0    5.0
# RosalinaLuma  11.000    11.0   5.75          NaN     NaN     9.0    5.5
# Ryu           16.000    12.0  15.00       12.000    16.0     NaN    NaN
# Shulk         12.500     NaN    NaN       12.500     NaN     NaN    9.5
# Squirtle       1.000     NaN   1.50        8.000     NaN     NaN    9.0
# Terry         15.000    10.0  17.00       13.000    12.0     8.0    3.0
# Wario         12.000     7.0    NaN       11.000     NaN     NaN    4.0
# Wolf          11.000     NaN  13.00       11.000     NaN     8.5    6.0
# YoungLink        NaN     NaN  18.00       11.000     NaN     NaN   10.0
# Zelda         20.000    12.0  16.00       12.000     NaN     NaN    5.5
#
# Name            Fair  Fsmash  Fthrow  ...  Light Utilt  Medium Dtilt  \
# Owner                                 ...
# BanjoKazooie  15.000    16.0     NaN  ...          NaN           NaN
# Bowser        13.000    23.0    12.0  ...          NaN           NaN
# Chrom          9.025    18.0     5.0  ...          NaN           NaN
# Daisy         14.000    15.0     NaN  ...          NaN           NaN
# DarkPit          NaN     NaN     NaN  ...          NaN           NaN
# Falco          1.000    16.0     NaN  ...          NaN           NaN
# Fox              NaN    14.0     NaN  ...          NaN           NaN
# Ganondorf     17.000    24.0     NaN  ...          NaN           NaN
# Greninja      14.000    14.0     NaN  ...          NaN           NaN
# Hero          10.000    18.0     7.0  ...          NaN           NaN
# IceClimbers   12.000    12.0     NaN  ...          NaN           NaN
# Ike           11.500    19.0     NaN  ...          NaN           NaN
# Incineroar    12.000    16.0    12.0  ...          NaN           NaN
# Ivysaur       12.000    16.0     NaN  ...          NaN           NaN
# Joker            NaN    14.0     8.0  ...          NaN           NaN
# Ken           14.000    12.0     9.0  ...          2.0           7.0
# KingKRool     12.000     NaN    10.0  ...          NaN           NaN
# Kirby            NaN     NaN     5.0  ...          NaN           NaN
# LittleMac      5.000    20.0     NaN  ...          NaN           NaN
# Lucina        10.500    15.0     4.0  ...          NaN           NaN
# Marth          8.000    13.0     4.0  ...          NaN           NaN
# MetaKnight       NaN    16.0     NaN  ...          NaN           NaN
# Mewtwo        13.000     NaN     NaN  ...          NaN           NaN
# Palutena      10.000    16.0     9.0  ...          NaN           NaN
# Peach         14.000    15.0     NaN  ...          NaN           NaN
# PiranhaPlant   9.000    15.0     NaN  ...          NaN           NaN
# Pit              NaN     NaN     NaN  ...          NaN           NaN
# Ridley           NaN    20.0     9.0  ...          NaN           NaN
# Rob            7.000     NaN     8.0  ...          NaN           NaN
# RosalinaLuma   1.000     NaN     9.0  ...          NaN           NaN
# Ryu           14.000    16.0     9.0  ...          2.0           7.0
# Shulk          8.000     NaN     NaN  ...          NaN           NaN
# Squirtle       7.000    15.0     NaN  ...          NaN           NaN
# Terry         11.000    18.0    10.0  ...          NaN           NaN
# Wario          7.000    20.0     NaN  ...          NaN           NaN
# Wolf           9.000    15.0     NaN  ...          NaN           NaN
# YoungLink        NaN     NaN     NaN  ...          NaN           NaN
# Zelda         20.000     NaN    10.0  ...          NaN           NaN
#
# Name          Medium Jab 1  Medium Utilt  Nair  Rapid Jab   Uair  Usmash  \
# Owner
# BanjoKazooie           NaN           NaN   NaN        0.4    NaN    1.50
# Bowser                 NaN           NaN   NaN        NaN  15.00   22.00
# Chrom                  NaN           NaN   NaN        NaN   7.60     NaN
# Daisy                  NaN           NaN  13.0        NaN    NaN   17.00
# DarkPit                NaN           NaN   NaN        0.5    NaN     NaN
# Falco                  NaN           NaN   NaN        0.3   9.00     NaN
# Fox                    NaN           NaN   9.0        NaN    NaN   16.00
# Ganondorf              NaN           NaN   NaN        NaN  12.00   24.00
# Greninja               NaN           NaN  11.0        0.5    NaN     NaN
# Hero                   NaN           NaN   9.0        NaN   7.00   14.00
# IceClimbers            NaN           NaN   7.0        NaN   9.00   11.00
# Ike                    NaN           NaN   7.5        NaN  11.00   17.00
# Incineroar             NaN           NaN  13.0        NaN   8.00   17.00
# Ivysaur                NaN           NaN   1.0        0.5  15.00   17.00
# Joker                  NaN           NaN   7.0        NaN   0.75   12.00
# Ken                   12.0          12.0   6.5        NaN   6.50   17.00
# KingKRool              NaN           NaN  12.0        NaN  14.00     NaN
# Kirby                  NaN           NaN   8.0        0.2   9.00   14.00
# LittleMac              NaN           NaN   2.0        0.5   5.00   21.00
# Lucina                 NaN           NaN   NaN        NaN  11.40   14.25
# Marth                  NaN           NaN   NaN        NaN   9.50   13.00
# MetaKnight             NaN           NaN  10.0        1.0   4.00     NaN
# Mewtwo                 NaN           NaN   NaN        0.8  12.00     NaN
# Palutena               NaN           NaN   1.4        0.6   1.00   16.00
# Peach                  NaN           NaN  13.0        NaN    NaN   17.00
# PiranhaPlant           NaN           NaN   2.0        0.6   8.00     NaN
# Pit                    NaN           NaN   NaN        0.5    NaN     NaN
# Ridley                 NaN           NaN   9.0        0.7  12.00   17.00
# Rob                    NaN           NaN   7.5        NaN    NaN   14.00
# RosalinaLuma           NaN           NaN   8.0        0.3   5.00   12.00
# Ryu                   12.0          12.0   8.0        NaN    NaN   17.00
# Shulk                  NaN           NaN   8.5        NaN    NaN     NaN
# Squirtle               NaN           NaN  10.0        NaN   7.00   10.00
# Terry                  NaN           NaN   7.0        NaN   9.00   16.00
# Wario                  NaN           NaN   NaN        NaN  13.00   17.00
# Wolf                   NaN           NaN  12.0        NaN  12.00     NaN
# YoungLink              NaN           NaN  10.0        0.3  15.00     NaN
# Zelda                  NaN           NaN   NaN        0.2  17.00    1.40
#
# Name          Uthrow  Utilt
# Owner
# BanjoKazooie     NaN  10.00
# Bowser           NaN  11.00
# Chrom            6.0  10.45
# Daisy            NaN   8.00
# DarkPit          NaN    NaN
# Falco            4.0    NaN
# Fox              NaN   6.00
# Ganondorf        NaN  24.00
# Greninja         5.0   4.50
# Hero             7.0   9.00
# IceClimbers      NaN    NaN
# Ike              NaN  12.00
# Incineroar      12.0   9.00
# Ivysaur          NaN   7.00
# Joker            7.0   1.00
# Ken              8.0    NaN
# KingKRool       16.0  11.50
# Kirby           10.0   5.00
# LittleMac        NaN   6.50
# Lucina           5.0   7.60
# Marth            5.0   6.00
# MetaKnight      10.0   7.00
# Mewtwo          12.0   7.00
# Palutena         8.0   1.40
# Peach            NaN   8.00
# PiranhaPlant    12.0   7.00
# Pit              NaN    NaN
# Ridley           NaN   7.00
# Rob             12.0    NaN
# RosalinaLuma     7.0  10.00
# Ryu              8.0    NaN
# Shulk            NaN  10.00
# Squirtle         NaN   5.00
# Terry            NaN  11.00
# Wario            NaN   6.00
# Wolf             NaN  10.00
# YoungLink        NaN   8.00
# Zelda           11.0   7.20
#
# [38 rows x 24 columns]

# %%
#Split the Values for Angle and Use the First Value
moves1['Angle'] = moves1['Angle'].astype(str)
moves1['Angle'] = moves1['Angle'].str.split(pat="/")
moves1['Angle'] = moves1['Angle'].map(lambda x: x[0])
#Method to Convert Elements Containing Strings Back to Numeric Data Found at https://stackoverflow.com/questions/42719749/pandas-convert-string-to-int
moves1['Angle'] = pd.to_numeric(moves1['Angle'], errors='coerce')
#print(moves1['Angle'])

#Create the Pivot Table
angle_pivot = moves1.pivot_table(index='Owner', columns='Name', aggfunc=np.mean, values='Angle')
angle_pivot = angle_pivot[['Bair', 'Bthrow', 'Dair', 'Dash Attack', 'Dsmash', 'Dthrow',
                            'Dtilt', 'Fair', 'Fsmash', 'Fthrow', 'Ftilt', 'Jab 1', 'Jab 2', 'Jab 3','Light Utilt',
                            'Medium Dtilt', 'Medium Jab 1', 'Medium Utilt',
                            'Nair', 'Rapid Jab', 'Uair', 'Usmash', 'Uthrow', 'Utilt']]
angle_pivot
# Out:
# Name           Bair  Bthrow   Dair  Dash Attack  Dsmash  Dthrow  Dtilt   Fair  \
# Owner
# BanjoKazooie    NaN    45.0  270.0         62.0    48.0     NaN   32.0   44.0
# Bowser         35.0    45.0  275.0         80.0     NaN    50.0    NaN  361.0
# Chrom         361.0   117.0  270.0         52.0     NaN    80.0   30.0  361.0
# Daisy         361.0   140.0    NaN          NaN     NaN   106.0  275.0   42.0
# DarkPit        43.0    45.0  270.0         60.0     NaN    70.0   75.0    NaN
# Falco         361.0    35.0  285.0         65.0    25.0    50.0   75.0  367.0
# Fox            30.0     NaN    NaN         70.0    25.0     NaN   77.0    NaN
# Ganondorf     361.0    43.0  270.0         70.0     NaN    65.0   60.0  361.0
# Greninja        NaN   140.0  270.0         70.0    30.0    65.0   79.0   45.0
# Hero           36.0    47.0  270.0         50.0     NaN    74.0   77.0  361.0
# IceClimbers   361.0    60.0   70.0         80.0    60.0    80.0   20.0   40.0
# Ike           361.0    28.0   50.0         52.0     NaN    80.0   80.0   30.0
# Incineroar    361.0    47.0  361.0         55.0   361.0    68.0   89.0  361.0
# Ivysaur         NaN    45.0  270.0         74.0   361.0    80.0   30.0   80.0
# Joker          43.0   131.0   38.0          NaN     NaN    79.0   82.0    NaN
# Ken           361.0    52.0  300.0         50.0    35.0    76.0    NaN   61.0
# KingKRool      45.0    45.0  270.0         45.0   361.0     NaN  361.0  361.0
# Kirby         361.0   130.0    NaN         76.0    29.0    63.0  361.0    NaN
# LittleMac      30.0    45.0  361.0         50.0     NaN    87.0   80.0   30.0
# Lucina        361.0   140.0  270.0         45.0     NaN   100.0   30.0  361.0
# Marth         361.0   140.0  270.0         45.0     NaN   100.0   30.0  361.0
# MetaKnight      NaN    45.0   35.0         60.0     NaN    60.0  361.0    NaN
# Mewtwo        361.0    47.0  270.0         54.0    55.0    74.0   80.0   47.0
# Palutena      361.0   361.0  270.0         70.0    60.0    73.0   35.0   45.0
# Peach         361.0   140.0    NaN          NaN     NaN   106.0  275.0   42.0
# PiranhaPlant  361.0    45.0  361.0         55.0     NaN    66.0   73.0  361.0
# Pit            43.0    45.0  270.0         60.0     NaN    70.0   75.0    NaN
# Ridley        361.0    47.0  275.0         42.0    85.0    74.0   78.0    NaN
# Rob            35.0    45.0   80.0         60.0     NaN     NaN  361.0  361.0
# RosalinaLuma   30.0    50.0  236.5          NaN     NaN    70.0   30.0   70.0
# Ryu           361.0    52.0  300.0         50.0    35.0    76.0    NaN   61.0
# Shulk         361.0   135.0    NaN         65.0     NaN    60.0   60.0  361.0
# Squirtle       38.0     NaN   98.0         65.0     NaN     NaN   38.0   48.0
# Terry          38.0    45.0  310.0         55.0    32.0   100.0   80.0   48.0
# Wario         361.0    45.0    NaN         50.0     NaN   130.0   46.0  361.0
# Wolf          361.0    50.0  270.0         80.0     NaN    44.0  361.0   60.0
# YoungLink       NaN   130.0   70.0         45.0     NaN    86.0   80.0    NaN
# Zelda         361.0    45.0  270.0         50.0     NaN   104.0   62.0  361.0
#
# Name          Fsmash  Fthrow  ...  Light Utilt  Medium Dtilt  Medium Jab 1  \
# Owner                         ...
# BanjoKazooie   361.0    48.0  ...          NaN           NaN           NaN
# Bowser         361.0    45.0  ...          NaN           NaN           NaN
# Chrom          361.0    45.0  ...          NaN           NaN           NaN
# Daisy           45.0    45.0  ...          NaN           NaN           NaN
# DarkPit          NaN    45.0  ...          NaN           NaN           NaN
# Falco          361.0    45.0  ...          NaN           NaN           NaN
# Fox            361.0     NaN  ...          NaN           NaN           NaN
# Ganondorf       40.0    43.0  ...          NaN           NaN           NaN
# Greninja       361.0    40.0  ...          NaN           NaN           NaN
# Hero           361.0    36.0  ...          NaN           NaN           NaN
# IceClimbers    361.0    45.0  ...          NaN           NaN           NaN
# Ike            361.0    28.0  ...          NaN           NaN           NaN
# Incineroar      47.0    45.0  ...          NaN           NaN           NaN
# Ivysaur        361.0    45.0  ...          NaN           NaN           NaN
# Joker          361.0    45.0  ...          NaN           NaN           NaN
# Ken            361.0    50.0  ...         90.0          64.0          85.0
# KingKRool        NaN    52.0  ...          NaN           NaN           NaN
# Kirby            NaN    75.0  ...          NaN           NaN           NaN
# LittleMac      361.0    45.0  ...          NaN           NaN           NaN
# Lucina         361.0    50.0  ...          NaN           NaN           NaN
# Marth          361.0    50.0  ...          NaN           NaN           NaN
# MetaKnight     361.0    65.0  ...          NaN           NaN           NaN
# Mewtwo           NaN    38.0  ...          NaN           NaN           NaN
# Palutena       361.0    45.0  ...          NaN           NaN           NaN
# Peach           45.0    45.0  ...          NaN           NaN           NaN
# PiranhaPlant    45.0    45.0  ...          NaN           NaN           NaN
# Pit              NaN    45.0  ...          NaN           NaN           NaN
# Ridley         361.0    42.0  ...          NaN           NaN           NaN
# Rob              NaN    45.0  ...          NaN           NaN           NaN
# RosalinaLuma     NaN    45.0  ...          NaN           NaN           NaN
# Ryu            361.0    50.0  ...         90.0          64.0          85.0
# Shulk            NaN    45.0  ...          NaN           NaN           NaN
# Squirtle       361.0     NaN  ...          NaN           NaN           NaN
# Terry          361.0    45.0  ...          NaN           NaN           NaN
# Wario          361.0    45.0  ...          NaN           NaN           NaN
# Wolf           361.0    37.0  ...          NaN           NaN           NaN
# YoungLink        NaN    52.0  ...          NaN           NaN           NaN
# Zelda            NaN    45.0  ...          NaN           NaN           NaN
#
# Name          Medium Utilt   Nair  Rapid Jab   Uair  Usmash  Uthrow  Utilt
# Owner
# BanjoKazooie           NaN    NaN      361.0    NaN   367.0    88.0   86.0
# Bowser                 NaN    NaN        NaN   85.0    90.0    82.0  100.0
# Chrom                  NaN    NaN        NaN   80.0     NaN    97.0   98.0
# Daisy                  NaN  361.0        NaN    NaN    90.0    88.0   92.0
# DarkPit                NaN    NaN      361.0    NaN     NaN    90.0    NaN
# Falco                  NaN    NaN      361.0   65.0     NaN    94.0    NaN
# Fox                    NaN  361.0        NaN    NaN    80.0     NaN  110.0
# Ganondorf              NaN    NaN        NaN   30.0    85.0    90.0  361.0
# Greninja               NaN   60.0      361.0    NaN     NaN    93.0   92.0
# Hero                   NaN   57.0        NaN   73.0    87.0    89.0   92.0
# IceClimbers            NaN  361.0        NaN   70.0    83.0    88.0    NaN
# Ike                    NaN   80.0        NaN   80.0    82.0    87.0   95.0
# Incineroar             NaN  361.0        NaN   85.0    88.0    88.0   86.0
# Ivysaur                NaN  361.0      361.0   90.0    82.0    90.0   88.0
# Joker                  NaN   46.0        NaN   80.0    83.0    90.0  367.0
# Ken                   80.0  361.0        NaN   75.0    83.0    88.0    NaN
# KingKRool              NaN  361.0        NaN   85.0     NaN    90.0   50.0
# Kirby                  NaN   46.0      361.0   70.0    88.0    78.0  100.0
# LittleMac              NaN  367.0      361.0   80.0    86.0    85.0   96.0
# Lucina                 NaN    NaN        NaN   85.0    89.0    93.0  100.0
# Marth                  NaN    NaN        NaN   80.0    89.0    93.0  100.0
# MetaKnight             NaN  361.0      361.0   67.0     NaN    77.0   95.0
# Mewtwo                 NaN    NaN      361.0   72.0     NaN    90.0  110.0
# Palutena               NaN  367.0      361.0  105.0    88.0    92.0  367.0
# Peach                  NaN  361.0        NaN    NaN    90.0    88.0   92.0
# PiranhaPlant           NaN  367.0      361.0   85.0     NaN    90.0   80.0
# Pit                    NaN    NaN      361.0    NaN     NaN    90.0    NaN
# Ridley                 NaN   44.0      361.0   86.0    82.0    89.0   88.0
# Rob                    NaN   70.0        NaN    NaN    80.0    80.0    NaN
# RosalinaLuma           NaN   60.0      361.0   88.0    86.0    88.0   88.0
# Ryu                   80.0  361.0        NaN    NaN    83.0    88.0    NaN
# Shulk                  NaN   50.0        NaN    NaN     NaN    88.0   85.0
# Squirtle               NaN   42.0        NaN   64.0    95.0     NaN   88.0
# Terry                  NaN   62.0        NaN   75.0    89.0    80.0   78.0
# Wario                  NaN    NaN        NaN   88.0    95.0    89.0   92.0
# Wolf                   NaN  361.0        NaN   80.0     NaN    80.0   80.0
# YoungLink              NaN  361.0      361.0   80.0     NaN    90.0   85.0
# Zelda                  NaN    NaN      361.0   90.0    90.0    87.0  100.0
#
# [38 rows x 24 columns]

# %%
#Split the Values for Base Knockback and Use the First Value
moves1['BaseKnockBackSetKnockback'] = moves1['BaseKnockBackSetKnockback'].astype(str)
moves1['BaseKnockBackSetKnockback'] = moves1['BaseKnockBackSetKnockback'].str.split(pat="/")
moves1['BaseKnockBackSetKnockback'] = moves1['BaseKnockBackSetKnockback'].map(lambda x: x[0])
#Method to Convert Elements Containing Strings Back to Numeric Data Found at https://stackoverflow.com/questions/42719749/pandas-convert-string-to-int
moves1['BaseKnockBackSetKnockback'] = pd.to_numeric(moves1['BaseKnockBackSetKnockback'], errors='coerce')
#print(moves1['BaseKnockBackSetKnockback'])

#Create the Pivot Table
knockback_pivot = moves1.pivot_table(index='Owner', columns='Name', aggfunc=np.mean, values='BaseKnockBackSetKnockback')
knockback_pivot = knockback_pivot[['Bair', 'Bthrow', 'Dair', 'Dash Attack', 'Dsmash', 'Dthrow',
                            'Dtilt', 'Fair', 'Fsmash', 'Fthrow', 'Ftilt', 'Jab 1', 'Jab 2', 'Jab 3','Light Utilt',
                            'Medium Dtilt', 'Medium Jab 1', 'Medium Utilt',
                            'Nair', 'Rapid Jab', 'Uair', 'Usmash', 'Uthrow', 'Utilt']]
knockback_pivot
# Out:
# Name          Bair  Bthrow   Dair  Dash Attack  Dsmash  Dthrow  Dtilt  Fair  \
# Owner
# BanjoKazooie   NaN    64.0  20.00         74.0    62.0     NaN   64.0  36.0
# Bowser        20.0    60.0  30.00         95.0     NaN    90.0    NaN  40.0
# Chrom         36.0    70.0  20.00         65.0     NaN    65.0   50.0  53.0
# Daisy         30.0    35.0    NaN          NaN     NaN    60.0   60.0  50.0
# DarkPit       30.0     NaN   0.00         80.0     NaN    80.0   70.0   NaN
# Falco          0.0    70.0  10.00         80.0    20.0    60.0   50.0   NaN
# Fox           20.0     NaN    NaN         55.0    30.0     NaN   70.0   NaN
# Ganondorf     40.0    30.0  20.00         50.0     NaN    70.0   30.0  20.0
# Greninja       NaN    55.0  20.00         90.0    32.0    53.0   30.0  30.0
# Hero          32.0    70.0  15.00         70.0     NaN    77.0   74.0  36.0
# IceClimbers   25.0    80.0  40.00         90.0    45.0    30.0   40.0  40.0
# Ike           30.0    55.0  30.00         70.0     NaN    75.0   70.0  55.0
# Incineroar    66.0    57.0  50.00         70.0    75.0    70.0   60.0  33.0
# Ivysaur        NaN    60.0  27.00         80.0    40.0    44.0   50.0  51.0
# Joker         54.0    70.0  40.00          NaN     NaN    55.0   75.0   NaN
# Ken           21.0    75.0  10.00         80.0    50.0    50.0    NaN  82.0
# KingKRool     15.0    70.0  10.00         80.0    65.0     NaN   40.0  35.0
# Kirby         15.0    30.0    NaN         80.0    25.0    60.0   30.0   NaN
# LittleMac     25.0    42.0   0.00         80.0     NaN    50.0   50.0  25.0
# Lucina        40.0    80.0  20.00         75.0     NaN    95.0   45.0  40.0
# Marth         40.0    80.0  20.00         70.0     NaN    95.0   40.0  40.0
# MetaKnight     NaN    60.0  30.00         65.0     NaN    50.0   15.0   NaN
# Mewtwo        20.0    70.0  10.00         80.0    20.0    65.0   60.0  40.0
# Palutena      30.0    65.0  20.00         71.0    40.0    90.0   40.0  31.0
# Peach         30.0    35.0    NaN          NaN     NaN    60.0   60.0  50.0
# PiranhaPlant  23.0    54.0  15.00        100.0     NaN    80.0   55.0  50.0
# Pit           30.0     NaN   0.00         80.0     NaN    80.0   70.0   NaN
# Ridley        35.0    70.0  55.00         70.0    69.0    40.0   65.0   NaN
# Rob           41.0    60.0  10.00         70.0     NaN     NaN    2.0  30.0
# RosalinaLuma  38.0    70.0  23.75          NaN     NaN    90.0   35.0  90.0
# Ryu           21.0    75.0  10.00         80.0    50.0    50.0    NaN  82.0
# Shulk         35.0    70.0    NaN         70.0     NaN    85.0   45.0  46.0
# Squirtle      30.0     NaN    NaN         70.0     NaN     NaN   53.0  50.0
# Terry         30.0    60.0  15.00         65.0    36.0    80.0   25.0  45.0
# Wario         21.0    80.0    NaN         60.0     NaN    80.0   20.0  30.0
# Wolf          37.0    40.0   6.00         40.0     NaN    50.0   25.0  45.0
# YoungLink      NaN    45.0  30.00         70.0     NaN    70.0   80.0   NaN
# Zelda         30.0    40.0  30.00         85.0     NaN    75.0   15.0  24.0
#
# Name          Fsmash  Fthrow  ...  Light Utilt  Medium Dtilt  Medium Jab 1  \
# Owner                         ...
# BanjoKazooie    36.0    68.0  ...          NaN           NaN           NaN
# Bowser          25.0    60.0  ...          NaN           NaN           NaN
# Chrom           60.0    70.0  ...          NaN           NaN           NaN
# Daisy           60.0    48.0  ...          NaN           NaN           NaN
# DarkPit          NaN    50.0  ...          NaN           NaN           NaN
# Falco           42.0    35.0  ...          NaN           NaN           NaN
# Fox             28.0     NaN  ...          NaN           NaN           NaN
# Ganondorf       61.0    68.0  ...          NaN           NaN           NaN
# Greninja        35.0    65.0  ...          NaN           NaN           NaN
# Hero            62.0    80.0  ...          NaN           NaN           NaN
# IceClimbers     50.0    70.0  ...          NaN           NaN           NaN
# Ike             40.0    55.0  ...          NaN           NaN           NaN
# Incineroar      65.0    82.0  ...          NaN           NaN           NaN
# Ivysaur         45.0    80.0  ...          NaN           NaN           NaN
# Joker           40.0    65.0  ...          NaN           NaN           NaN
# Ken             26.0    75.0  ...         19.0          70.0          70.0
# KingKRool        NaN    60.0  ...          NaN           NaN           NaN
# Kirby            NaN    40.0  ...          NaN           NaN           NaN
# LittleMac       29.0    45.0  ...          NaN           NaN           NaN
# Lucina          65.0   100.0  ...          NaN           NaN           NaN
# Marth           48.0   100.0  ...          NaN           NaN           NaN
# MetaKnight      30.0    50.0  ...          NaN           NaN           NaN
# Mewtwo           NaN    50.0  ...          NaN           NaN           NaN
# Palutena        40.0    90.0  ...          NaN           NaN           NaN
# Peach           60.0    48.0  ...          NaN           NaN           NaN
# PiranhaPlant    25.0    60.0  ...          NaN           NaN           NaN
# Pit              NaN    50.0  ...          NaN           NaN           NaN
# Ridley          58.0    60.0  ...          NaN           NaN           NaN
# Rob              NaN    60.0  ...          NaN           NaN           NaN
# RosalinaLuma     NaN    45.0  ...          NaN           NaN           NaN
# Ryu             26.0    75.0  ...         19.0          70.0          70.0
# Shulk            NaN    60.0  ...          NaN           NaN           NaN
# Squirtle        35.0     NaN  ...          NaN           NaN           NaN
# Terry           60.0    60.0  ...          NaN           NaN           NaN
# Wario           20.0    60.0  ...          NaN           NaN           NaN
# Wolf            30.0    55.0  ...          NaN           NaN           NaN
# YoungLink        NaN    45.0  ...          NaN           NaN           NaN
# Zelda            NaN   100.0  ...          NaN           NaN           NaN
#
# Name          Medium Utilt  Nair  Rapid Jab  Uair  Usmash  Uthrow  Utilt
# Owner
# BanjoKazooie           NaN   NaN       16.0   NaN     NaN    72.0   42.0
# Bowser                 NaN   NaN        NaN  35.0    23.0    25.0   55.0
# Chrom                  NaN   NaN        NaN  40.0     NaN    60.0   35.0
# Daisy                  NaN  20.0        NaN   NaN    24.0    72.0   65.0
# DarkPit                NaN   NaN        8.0   NaN     NaN    70.0    NaN
# Falco                  NaN   NaN        6.0  38.0     NaN    60.0    NaN
# Fox                    NaN  10.0        NaN   NaN    30.0     NaN   20.0
# Ganondorf              NaN   NaN        NaN  30.0    40.0    70.0   60.0
# Greninja               NaN  30.0        8.0   NaN     NaN    60.0   60.0
# Hero                   NaN  66.0        NaN  49.0    60.0    65.0   80.0
# IceClimbers            NaN  20.0        NaN  20.0    50.0   120.0    NaN
# Ike                    NaN  35.0        NaN  55.0    50.0    70.0   50.0
# Incineroar             NaN  50.0        NaN  65.0    94.0    68.0   50.0
# Ivysaur                NaN  12.0        7.0  64.0    78.0    75.0   85.0
# Joker                  NaN  35.0        NaN  20.0    43.0    70.0   20.0
# Ken                   70.0  20.0        NaN  20.0    32.0    55.0    NaN
# KingKRool              NaN  40.0        NaN  56.0     NaN    85.0   50.0
# Kirby                  NaN  30.0        7.0  20.0    20.0    75.0   30.0
# LittleMac              NaN   NaN       14.0  25.0    40.0    70.0   25.0
# Lucina                 NaN   NaN        NaN  40.0    42.0    70.0   65.0
# Marth                  NaN   NaN        NaN  40.0    45.0    70.0   65.0
# MetaKnight             NaN  40.0       10.0  30.0     NaN    70.0   60.0
# Mewtwo                 NaN   NaN        8.0  40.0     NaN    72.0   70.0
# Palutena               NaN   0.0       10.0   NaN    53.0    90.0    NaN
# Peach                  NaN  20.0        NaN   NaN    24.0    72.0   65.0
# PiranhaPlant           NaN  10.0        8.0  40.0     NaN    64.0   55.0
# Pit                    NaN   NaN        8.0   NaN     NaN    70.0    NaN
# Ridley                 NaN  55.0       14.0  70.0    58.0    55.0   30.0
# Rob                    NaN  52.0        NaN   NaN    40.0    60.0    NaN
# RosalinaLuma           NaN  45.0        8.0  40.0    45.0    50.0   75.0
# Ryu                   70.0  20.0        NaN   NaN    32.0    55.0    NaN
# Shulk                  NaN  40.0        NaN   NaN     NaN    60.0   70.0
# Squirtle               NaN  32.0        NaN  40.0    60.0     NaN   30.0
# Terry                  NaN  20.0        NaN  25.0    32.0    70.0   72.0
# Wario                  NaN   NaN        NaN  30.0    35.0    60.0   28.0
# Wolf                   NaN  30.0        NaN  30.0     NaN    75.0   30.0
# YoungLink              NaN  20.0        8.0  25.0     NaN    30.0   20.0
# Zelda                  NaN   NaN        7.0  55.0     NaN    50.0   45.0
#
# [38 rows x 24 columns]

# %%
#Create Pivot Table without Aggregation
#Method Found at https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pivot.html

#Create a Copy of the Table for Operations
movement1 = movement_df.copy()

#Split the Values Using Delimiters
movement1['Value'] = movement1['Value'].str.split(pat=" ")
movement1['Value'] = movement1['Value'].map(lambda x: x[0])

movement_pivot = movement1.pivot(index='Owner', columns='Name', values='Value')
print(len(movement_pivot))
movement_pivot
# Out:
# 44
# Name         Air Acceleration Air Speed Crawl FH Air Time Fall Speed  \
# Owner
# BanjoKazooie             0.07      0.92    No          44       1.76
# Bowser                   0.05     1.155   Yes          45       1.77
# Chrom                    0.05     1.302    No          44        1.8
# Daisy                    0.12     1.029    No          57       1.19
# DarkPit                 0.075     0.935    No          52       1.48
# Falco                     0.1     0.977                57        1.8
# Fox                      0.09      1.11    No          36        2.1
# Ganondorf                0.04      0.83    No          41       1.65
# Greninja                 0.08     1.239   Yes          49       1.85
# Hero                    0.055      1.01    No      frames       1.57
# IceClimbers              0.09      0.83    No          62        1.3
# Ike                      0.05     1.134    No          48       1.65
# Incineroar               0.07      0.88    No          43       1.76
# Inkling                  0.08     1.208   Yes          52       1.58
# Ivysaur                 0.095     0.998   Yes          54       1.38
# Joker                    0.08       1.1    No          45       1.63
# Ken                     0.035      1.12    No          40        1.6
# KingKRool                0.05     0.945    No          48        1.7
# Kirby                   0.068      0.84    No          53       1.23
# LittleMac                0.04     1.208    No          44       1.95
# Lucina                   0.08     1.071    No          55       1.58
# Marth                    0.08     1.071    No          55       1.58
# MetaKnight              0.075      1.04    No          47       1.66
# Mewtwo                   0.07     1.313    No          52       1.55
# Palutena                0.105         1    No          50       1.55
# Peach                    0.12     1.029    No          57       1.19
# Pichu                     0.1     1.029   Yes          45        1.9
# PiranhaPlant             0.06         1    No          45       1.95
# Pit                     0.075     0.935    No          52       1.48
# Richter                  0.03      0.94   Yes          51       1.85
# Ridley                   0.07      1.05    No          51       1.78
# Rob                     0.085     1.134    No          56        1.6
# RosalinaLuma             0.11      1.05   Yes          71        1.2
# Roy                      0.05     1.302    No          44        1.8
# Ryu                     0.035      1.12    No          40        1.6
# Shulk                    1.06     1.113    No          50       1.58
# Simon                    0.03      0.94   Yes          51       1.85
# Snake                    0.03     0.987   Yes          42       1.73
# Squirtle                0.105      1.01   Yes          51       1.35
# Terry                    0.06      0.95    No          46       1.48
# Wario                    0.12     1.271   Yes          46       1.61
# Wolf                     0.09     1.281    No          43        1.8
# YoungLink                0.06     0.966    No          49        1.8
# Zelda                   0.065     1.092    No          56       1.35
#
# Name         Fast Fall Speed Gravity Hard Landing Lag Jumpsquat Max Jumps  \
# Owner
# BanjoKazooie           2.816    0.11                4         3         3
# Bowser                 2.832   0.125                6         3         2
# Chrom                   2.88   0.114                5         3         2
# Daisy                  1.904    0.07                4         3         2
# DarkPit                2.368   0.081                5         3         4
# Falco                   2.88    0.13                4         3         2
# Fox                     3.36    0.23                4         3         2
# Ganondorf               2.64   0.108                5         3         2
# Greninja                2.96    0.18                4         3         2
# Hero                   2.512   0.094                4         3         2
# IceClimbers             2.08   0.082                4         3         2
# Ike                     2.64   0.092                4         3         2
# Incineroar             2.816   0.126                4         3         2
# Inkling                2.528   0.087                4         3         2
# Ivysaur                2.208   0.082                4         3         2
# Joker                  3.097   0.127                4         3         2
# Ken                     2.24    0.12                4         3         2
# KingKRool               2.72   0.105                6         3         2
# Kirby                  1.968   0.064                4         3         6
# LittleMac               3.12    0.09                4         3         2
# Lucina                 2.528   0.075                4         3         2
# Marth                  2.528   0.075                4         3         2
# MetaKnight             2.656    0.11                4         3         6
# Mewtwo                  2.48   0.082                5         3         2
# Palutena                2.48    0.12                4         3         2
# Peach                  1.904    0.07                4         3         2
# Pichu                    2.5    0.14                3         3         2
# PiranhaPlant            2.73    0.14                4         3         2
# Pit                    2.368   0.081                5         3         4
# Richter                 2.96   0.085                4         3         2
# Ridley                 2.848    0.09                4         3         3
# Rob                     2.56    0.09                4         3         2
# RosalinaLuma            1.92   0.062                4         3         2
# Roy                     2.88   0.114                5         3         2
# Ryu                     2.24    0.12                4         3         2
# Shulk                  2.528   0.098                4         3         2
# Simon                   2.96   0.085                4         3         2
# Snake                  2.768    0.08                4         3         2
# Squirtle                2.16   0.128                4         3         2
# Terry                  2.368    0.09                4         3         2
# Wario                  2.576   0.107                4         3         2
# Wolf                    2.88    0.13                4         3         2
# YoungLink               2.88   0.096                4         3         2
# Zelda                   2.16   0.071                4         3         2
#
# Name         Run Speed SH Air Time Soft Landing Lag Tether Walk Speed  \
# Owner
# BanjoKazooie      2.18          36                2     No       1.06
# Bowser           1.971          31                2     No      0.901
# Chrom            2.145          30                2     No      1.208
# Daisy            1.595          41                2     No      0.924
# DarkPit          1.828          38                2     No      1.259
# Falco            1.619          32                2     No      1.344
# Fox              2.402          24                2     No      1.523
# Ganondorf         1.34          30                2     No      0.767
# Greninja         2.288          32                2     No      1.502
# Hero              1.84      frames                2     No       0.98
# IceClimbers       1.53          41                2     No      1.008
# Ike              1.507          37                2     No      0.912
# Incineroar        1.18          30                2     No       0.62
# Inkling          1.925          40                2     No      1.134
# Ivysaur          1.595          39                2    Yes      1.103
# Joker             2.06          30                2    Yes       1.12
# Ken               1.76          31                2     No      0.825
# KingKRool        1.485          32                2     No      0.903
# Kirby            1.727          39                2     No      0.977
# LittleMac        2.464          33                2     No      1.386
# Lucina           1.964          41                2     No      1.575
# Marth            1.964          41                2     No      1.575
# MetaKnight        2.09          31                2     No      1.239
# Mewtwo           2.255          41                2     No       1.26
# Palutena         2.077          34                2     No      1.271
# Peach            1.595          41                2     No      0.924
# Pichu            1.892          31                2     No      1.302
# PiranhaPlant      1.72          31                2     No       0.76
# Pit              1.828          38                2     No      1.259
# Richter           1.52          41                2    Yes       0.76
# Ridley             2.2          35                2     No        1.1
# Rob              1.725          40                2     No      1.178
# RosalinaLuma     1.795          50                2     No      1.138
# Roy              2.145          30                2     No      1.208
# Ryu                1.6          31                2     No       0.75
# Shulk            1.672          37                2     No      1.155
# Simon             1.52          41                2    Yes       0.76
# Snake            1.595          37                2     No      0.882
# Squirtle          1.76          34                2     No      1.281
# Terry             1.72          36                2     No       0.85
# Wario             1.65          33                2     No      0.889
# Wolf              1.54          30                2     No      1.208
# YoungLink        1.749          36                2    Yes       1.26
# Zelda             1.43          41                2     No      0.914
#
# Name         Wall Cling Wall Jump Weight
# Owner
# BanjoKazooie         No        No    106
# Bowser               No        No    135
# Chrom                No        No     95
# Daisy                No        No     89
# DarkPit              No        No     96
# Falco                No       Yes     82
# Fox                  No       Yes     77
# Ganondorf            No        No    118
# Greninja             No       Yes     88
# Hero                 No        No    101
# IceClimbers          No        No     92
# Ike                  No        No    107
# Incineroar           No        No    116
# Inkling              No       Yes     94
# Ivysaur              No        No     96
# Joker                No       Yes     93
# Ken                  No        No    103
# KingKRool            No        No    133
# Kirby                No        No     79
# LittleMac            No       Yes     87
# Lucina               No        No     90
# Marth                No        No     90
# MetaKnight           No        No     80
# Mewtwo               No       Yes     79
# Palutena             No        No     91
# Peach                No        No     89
# Pichu                No       Yes     62
# PiranhaPlant         No        No    112
# Pit                  No        No     96
# Richter              No        No    107
# Ridley               No        No    107
# Rob                  No        No    106
# RosalinaLuma         No        No     82
# Roy                  No        No     95
# Ryu                  No        No    103
# Shulk                No        No     97
# Simon                No        No    107
# Snake                No        No    106
# Squirtle            Yes       Yes     75
# Terry                No        No    108
# Wario                No        No    107
# Wolf                 No       Yes     92
# YoungLink            No       Yes     88
# Zelda                No        No     85

# %%
#Create Pivot Table without Aggregation
#Method Found at https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pivot.html

#Create a Copy of the Table for Operations
character_attributes1 = attributes_df.copy()

#Obtain the First Values for Each Element
character_attributes1['Values'] = character_attributes1['Values'].map(lambda x: x[0]['Value'])
character_attributes1['Values'] = character_attributes1['Values'].str.split(pat="-")
character_attributes1['Values'] = character_attributes1['Values'].map(lambda x: x[0])
character_attributes1['Values'] = pd.to_numeric(character_attributes1['Values'], errors='coerce')
#print(character_attributes1['Values'])

character_attributes_pivot = character_attributes1.pivot_table(index='Owner', columns='Name', aggfunc=np.mean, values='Values')
print(len(character_attributes_pivot))
character_attributes_pivot
# Out:
# 39
# Name          AirAcceleration  AirSpeed  FallSpeed  RunSpeed  WalkSpeed  \
# Owner
# Bowser                 0.0550    1.1445     1.7100    2.0075     0.9125
# Chrom                  0.0300    1.3020     1.8000    2.2000     1.2080
# Daisy                  0.0800    1.0290     1.1900    1.8260     0.9240
# DarkPit                   NaN       NaN        NaN       NaN        NaN
# Falco                  0.0775    1.0975     1.8325    2.0075     1.1655
# Fox                    0.0800    1.1100     2.1000    2.0900     1.5230
# Ganondorf              0.0300    0.8300     1.6500    1.8700     0.7670
# Greninja               0.0700    1.2390     1.8500    2.1780     1.5020
# IceClimbers               NaN       NaN     1.3000    1.6800        NaN
# Ike                    0.0400    1.1340     1.6500    1.8150     0.9120
# Incineroar             0.0600    0.8800     1.7600    1.7600     0.6200
# Inkling                0.0700    1.2080     1.5800    2.1180     1.1340
# Ivysaur                0.0850    0.9980     1.3800    1.9030     1.1030
# Ken                    0.0250    1.1200     1.6000    1.9360     0.8250
# KingKRool              0.0400    0.9450     1.7000    1.9360     0.9030
# Kirby                  0.0650    0.8400     1.2300    1.9000     0.9770
# LittleMac              0.0300    1.2080     1.9500    2.3650     1.3860
# Lucina                 0.0700    1.0710     1.5800    2.2550     1.5750
# Marth                  0.0700    1.0710     1.5800    2.2550     1.5750
# MetaKnight             0.0650    1.0400     1.6600    2.2110     1.2390
# Mewtwo                 0.0500    1.3130     1.5500    2.2550     1.2600
# Palutena               0.1050    1.0000     1.5500    2.0350     1.2710
# Peach                  0.0800    1.0290     1.1900    1.8260     0.9240
# Pichu                  0.0900    1.0290     1.9000    1.9800     1.3020
# PiranhaPlant           0.0500    1.0000     1.9500    1.8200     0.7600
# Pit                    0.0650    0.9350     1.4800    2.0900     1.2590
# Richter                0.0200    0.9400     1.8500    1.7300     0.7600
# Ridley                 0.0600    1.0500     1.7800    1.8000     1.1000
# Rob                    0.0700    1.0500     1.5000    1.8150     0.9360
# RosalinaLuma           0.1000    1.0500     1.2000    2.0350     1.1380
# Roy                    0.0300    1.3020     1.8000    2.2000     1.2080
# Ryu                    0.0250    1.1200     1.6000    1.7600     0.7500
# Shulk                  0.0400    1.1130     1.5800    1.8700     1.1550
# Simon                  0.0200    0.9400     1.8500    1.7300     0.7600
# Snake                  0.0200    0.9870     1.7300    1.7600     0.8820
# Squirtle               0.0950    1.0100     1.3500    1.9360     1.2810
# Wario                  0.0800    1.2710     1.6100    1.8370     0.8890
# Wolf                   0.0800    1.2810     1.8000    2.0900     1.2080
# Zelda                  0.0550    1.0920     1.3500    1.9580     0.9140
#
# Name          Weight
# Owner
# Bowser         121.5
# Chrom           95.0
# Daisy           89.0
# DarkPit         96.0
# Falco           93.0
# Fox             77.0
# Ganondorf      118.0
# Greninja        88.0
# IceClimbers     92.0
# Ike            107.0
# Incineroar     116.0
# Inkling         94.0
# Ivysaur         96.0
# Ken            103.0
# KingKRool      133.0
# Kirby           79.0
# LittleMac       87.0
# Lucina          90.0
# Marth           90.0
# MetaKnight      80.0
# Mewtwo          77.0
# Palutena        91.0
# Peach           89.0
# Pichu           62.0
# PiranhaPlant   112.0
# Pit             96.0
# Richter        107.0
# Ridley         107.0
# Rob             95.0
# RosalinaLuma    82.0
# Roy             95.0
# Ryu            103.0
# Shulk           97.0
# Simon          107.0
# Snake          106.0
# Squirtle        75.0
# Wario          107.0
# Wolf            92.0
# Zelda           85.0

# %%
print(len(moves1.groupby('Owner').mean()))
moves1.groupby('Owner').mean()
# Out:
# 44
#               OwnerId  HitboxActive  FirstActionableFrame  BaseDamage  \
# Owner
# BanjoKazooie       76     11.465517             43.939394    5.230612
# Bowser              2     14.488889             53.344828   10.863158
# Chrom              61     16.555556             45.891892    7.802125
# Daisy              60     11.156250             44.666667    7.910714
# DarkPit             8     10.000000             46.416667    5.990323
# Falco              13     10.711111             42.870968    5.575000
# Fox                14     11.976190             40.391304    6.090000
# Ganondorf          15     19.744681             60.121212   15.198611
# Greninja           16     19.403846             54.078947    7.163636
# Hero               75     19.423529             51.391304    9.643210
# IceClimbers        77     11.608696             52.678571    5.660227
# Ike                17     23.444444             61.619048   13.634615
# Incineroar         59     16.942308             47.033333    8.785106
# Inkling            62     13.439024             42.407407         NaN
# Ivysaur            72     13.511111             51.062500    7.264103
# Joker              74     13.404255             44.585366    5.073364
# Ken                70      9.731343             44.435897    7.913333
# KingKRool          73     12.836735             52.277778    9.923810
# Kirby              20     12.870370             49.500000    8.572340
# LittleMac          22     21.135593             64.833333    9.600000
# Lucina             25      9.311111             49.324324    7.896154
# Marth              28      9.260870             49.324324    7.087500
# MetaKnight         30     13.510204             51.687500    7.038095
# Mewtwo             31     10.411765             46.535714    8.130769
# Palutena           39     13.976190             52.724138    6.486111
# Peach              40     11.156250             44.666667    7.910714
# Pichu              64     10.689655             41.272727         NaN
# PiranhaPlant       69     13.744186             47.138889    8.044444
# Pit                42     10.000000             46.000000    5.867742
# Richter            63     17.566667             45.636364         NaN
# Ridley             71     18.931818             51.333333    9.339927
# Rob                43     11.888889             47.700000    6.833333
# RosalinaLuma       45      9.560606             46.781250    4.981967
# Roy                46     10.138889             44.571429         NaN
# Ryu                47     11.324324             50.071429    9.025000
# Shulk              50     16.264151             49.758621    9.152273
# Simon              66     17.566667             45.636364         NaN
# Snake              65     13.933333             40.160000         NaN
# Squirtle           67     13.971429             45.625000    6.835714
# Terry              78     15.737864             48.027027    9.011765
# Wario              54     10.787879             49.961538    8.837500
# Wolf               68     11.482759             38.800000    8.189655
# YoungLink          79     15.620000             45.687500    6.483721
# Zelda              57     15.122449             48.676471    7.242000
#
#                    Angle  BaseKnockBackSetKnockback  IsWeightDependent
# Owner
# BanjoKazooie  175.820000                  47.244444              False
# Bowser        165.225000                  44.297297              False
# Chrom         161.707317                  48.088235              False
# Daisy         161.161290                  46.423077              False
# DarkPit       168.500000                  46.807692              False
# Falco         206.533333                  44.764706              False
# Fox           220.241379                  34.043478              False
# Ganondorf     173.102564                  46.135135              False
# Greninja      159.595745                  44.902439              False
# Hero          153.135802                  48.057971              False
# IceClimbers   179.826087                  41.152174              False
# Ike           161.966667                  48.066667              False
# Incineroar    155.062500                  63.048780              False
# Inkling              NaN                        NaN              False
# Ivysaur       138.650000                  45.555556              False
# Joker         216.490385                  40.343434              False
# Ken           103.508772                  51.958333              False
# KingKRool     189.853659                  53.275000              False
# Kirby         167.500000                  41.590909              False
# LittleMac     171.222222                  41.595745              False
# Lucina        220.692308                  50.236842              False
# Marth         217.550000                  48.794872              False
# MetaKnight    166.644444                  46.571429              False
# Mewtwo        190.857143                  45.666667              False
# Palutena      195.333333                  48.592593              False
# Peach         161.161290                  46.423077              False
# Pichu                NaN                        NaN              False
# PiranhaPlant  185.702703                  42.771429              False
# Pit           171.294118                  46.846154              False
# Richter              NaN                        NaN              False
# Ridley        185.195122                  54.567568              False
# Rob           160.896552                  42.200000              False
# RosalinaLuma  149.081967                  53.423729              False
# Roy                  NaN                        NaN              False
# Ryu            92.811594                  58.630769              False
# Shulk         186.250000                  47.789474              False
# Simon                NaN                        NaN              False
# Snake                NaN                        NaN              False
# Squirtle      121.230769                  46.250000              False
# Terry         100.184466                  60.314286              False
# Wario         150.000000                  42.034483              False
# Wolf          169.656250                  44.156250              False
# YoungLink     152.276596                  42.694444              False
# Zelda         213.117647                  49.714286              False

# %%
joined_hf = hitbox_pivot.join(faf_pivot, on='Owner', how="outer", lsuffix="_hitbox", rsuffix="_faf")
print(len(joined_hf))
joined_hf
# Out:
# 44
# Name          Airdodge_hitbox  Bair_hitbox  Dair_hitbox  Dash Attack_hitbox  \
# Owner
# BanjoKazooie              3.0          NaN         15.0                 9.0
# Bowser                    4.0          9.0         17.0                13.0
# Chrom                     3.0          8.0         16.0                13.0
# Daisy                     NaN          6.0          NaN                 NaN
# DarkPit                   NaN         10.0         10.0                 7.0
# Falco                     2.0          9.0         10.0                 8.0
# Fox                       NaN          9.0          NaN                 4.0
# Ganondorf                 4.0         10.0         16.0                10.0
# Greninja                  2.0          NaN         17.0                 7.0
# Hero                      3.0         18.0         16.0                21.0
# IceClimbers               3.0          8.0         12.0                11.0
# Ike                       NaN          7.0         16.0                15.0
# Incineroar                3.0          7.0         16.0                 8.0
# Inkling                   NaN          7.0         16.0                 9.0
# Ivysaur                   3.0          NaN         11.0                 4.0
# Joker                     NaN          7.0         13.0                 NaN
# Ken                       3.0          8.0          8.0                 7.0
# KingKRool                 4.0         18.0         14.0                 7.0
# Kirby                     3.0          6.0          NaN                18.0
# LittleMac                 2.0         11.0          7.0                 7.0
# Lucina                    3.0          7.0         11.0                13.0
# Marth                     3.0          7.0         11.0                13.0
# MetaKnight                2.0          NaN          4.0                 7.0
# Mewtwo                    3.0         13.0         15.0                10.0
# Palutena                  3.0          8.0         10.0                 6.0
# Peach                     NaN          6.0          NaN                 NaN
# Pichu                     NaN          NaN         14.0                 6.0
# PiranhaPlant              3.0         14.0          9.0                 7.0
# Pit                       NaN         10.0         10.0                 7.0
# Richter                   NaN         14.0         13.0                10.0
# Ridley                    3.0         10.0         11.0                12.0
# Rob                       3.0         19.0         20.0                 7.0
# RosalinaLuma              3.0          9.0         21.0                 NaN
# Roy                       NaN          8.0         16.0                13.0
# Ryu                       3.0          8.0          8.0                 7.0
# Shulk                     3.0         19.0          NaN                12.0
# Simon                     NaN         14.0         13.0                10.0
# Snake                     NaN          7.0          NaN                 5.0
# Squirtle                  NaN          5.0          6.0                 8.0
# Terry                     3.0         11.0         12.0                10.0
# Wario                     NaN          9.0          NaN                 5.0
# Wolf                      NaN         13.0         16.0                11.0
# YoungLink                 2.0          NaN         13.0                 8.0
# Zelda                     3.0          6.0         14.0                 6.0
#
# Name          Dash Grab_hitbox  Dsmash_hitbox  Dtilt_hitbox  Fair_hitbox  \
# Owner
# BanjoKazooie              10.0           13.0          12.0    15.000000
# Bowser                    11.0            NaN           NaN    11.000000
# Chrom                      8.0            NaN           7.0    10.000000
# Daisy                      9.0            NaN           8.0    16.000000
# DarkPit                    9.0            NaN           6.0          NaN
# Falco                      9.0            8.0          10.0     7.000000
# Fox                       10.0            6.0           7.0          NaN
# Ganondorf                 11.0            NaN          10.0    14.000000
# Greninja                  13.0           11.0           5.0    16.000000
# Hero                       9.0            NaN           6.0    14.000000
# IceClimbers               10.0            9.0           8.0    19.000000
# Ike                       10.0            NaN           7.0    11.000000
# Incineroar                12.0           18.0           9.0     8.000000
# Inkling                    9.0            NaN           NaN    10.000000
# Ivysaur                   13.0           13.0           4.0    14.000000
# Joker                      8.0            NaN          10.0          NaN
# Ken                        9.0            5.0           NaN     8.000000
# KingKRool                 11.0           22.0          13.0    12.000000
# Kirby                      9.0           10.0           4.0          NaN
# LittleMac                 13.0            NaN           3.0    10.000000
# Lucina                     9.0            NaN           7.0     6.000000
# Marth                      9.0            NaN           7.0     6.000000
# MetaKnight                11.0            NaN           3.0          NaN
# Mewtwo                    10.0           21.0           6.0     7.000000
# Palutena                  10.0           17.0          14.0     9.000000
# Peach                      9.0            NaN           8.0    16.000000
# Pichu                      8.0            NaN           7.0          NaN
# PiranhaPlant               9.0            NaN           9.0    10.000000
# Pit                        9.0            NaN           6.0          NaN
# Richter                   13.0            NaN           NaN    14.000000
# Ridley                    11.0           24.0           9.0          NaN
# Rob                        9.0            NaN           3.0     6.000000
# RosalinaLuma               9.0            NaN           5.0    13.333333
# Roy                        8.0            NaN           7.0    10.000000
# Ryu                        9.0            5.0           NaN     8.000000
# Shulk                     10.0            NaN          10.0    14.000000
# Simon                     13.0            NaN           NaN    14.000000
# Snake                     11.0            NaN           6.0    23.000000
# Squirtle                   8.0            NaN           8.0     5.000000
# Terry                      9.0            8.0           6.0     7.000000
# Wario                     11.0            NaN           5.0     5.000000
# Wolf                       8.0            NaN           5.0     7.000000
# YoungLink                 14.0            NaN           8.0          NaN
# Zelda                     13.0            NaN           5.0     6.000000
#
# Name          Fsmash_hitbox  Ftilt_hitbox  ...  Light Utilt_faf  \
# Owner                                      ...
# BanjoKazooie           19.0           NaN  ...              NaN
# Bowser                 22.0           NaN  ...              NaN
# Chrom                  13.0           8.0  ...              NaN
# Daisy                  15.0           8.0  ...              NaN
# DarkPit                 NaN          10.0  ...              NaN
# Falco                  17.0           NaN  ...              NaN
# Fox                    13.0           6.0  ...              NaN
# Ganondorf              29.0          10.0  ...              NaN
# Greninja               13.0          10.0  ...              NaN
# Hero                   17.0           NaN  ...              NaN
# IceClimbers            11.0           NaN  ...              NaN
# Ike                    31.0           NaN  ...              NaN
# Incineroar             16.0           NaN  ...              NaN
# Inkling                16.0           8.0  ...              NaN
# Ivysaur                15.0           NaN  ...              NaN
# Joker                  16.0           NaN  ...              NaN
# Ken                    13.0           NaN  ...             16.0
# KingKRool              19.0           NaN  ...              NaN
# Kirby                   NaN           NaN  ...              NaN
# LittleMac              14.0           NaN  ...              NaN
# Lucina                 10.0           8.0  ...              NaN
# Marth                  10.0           8.0  ...              NaN
# MetaKnight             24.0           NaN  ...              NaN
# Mewtwo                  NaN           NaN  ...              NaN
# Palutena               18.0           NaN  ...              NaN
# Peach                  15.0           8.0  ...              NaN
# Pichu                   NaN           5.0  ...              NaN
# PiranhaPlant           16.0           NaN  ...              NaN
# Pit                     NaN          10.0  ...              NaN
# Richter                24.0          12.0  ...              NaN
# Ridley                 18.0          10.0  ...              NaN
# Rob                     NaN           NaN  ...              NaN
# RosalinaLuma            NaN           7.0  ...              NaN
# Roy                    13.0           8.0  ...              NaN
# Ryu                    15.0           NaN  ...             16.0
# Shulk                   NaN          12.0  ...              NaN
# Simon                  24.0          12.0  ...              NaN
# Snake                  41.0           NaN  ...              NaN
# Squirtle               20.0           5.0  ...              NaN
# Terry                  18.0           8.0  ...              NaN
# Wario                  18.0           NaN  ...              NaN
# Wolf                   20.0           NaN  ...              NaN
# YoungLink               NaN          10.0  ...              NaN
# Zelda                   NaN           NaN  ...              NaN
#
# Name          Medium Dtilt_faf  Medium Jab 1_faf  Medium Utilt  Nair_faf  \
# Owner
# BanjoKazooie               NaN               NaN           NaN       NaN
# Bowser                     NaN               NaN           NaN       NaN
# Chrom                      NaN               NaN           NaN       NaN
# Daisy                      NaN               NaN           NaN      49.0
# DarkPit                    NaN               NaN           NaN       NaN
# Falco                      NaN               NaN           NaN       NaN
# Fox                        NaN               NaN           NaN      42.0
# Ganondorf                  NaN               NaN           NaN       NaN
# Greninja                   NaN               NaN           NaN      53.0
# Hero                       NaN               NaN           NaN      46.0
# IceClimbers                NaN               NaN           NaN      46.0
# Ike                        NaN               NaN           NaN      60.0
# Incineroar                 NaN               NaN           NaN      42.0
# Inkling                    NaN               NaN           NaN      32.0
# Ivysaur                    NaN               NaN           NaN      42.0
# Joker                      NaN               NaN           NaN      55.0
# Ken                       28.0              38.0          38.0      28.0
# KingKRool                  NaN               NaN           NaN      46.0
# Kirby                      NaN               NaN           NaN       NaN
# LittleMac                  NaN               NaN           NaN      16.0
# Lucina                     NaN               NaN           NaN       NaN
# Marth                      NaN               NaN           NaN       NaN
# MetaKnight                 NaN               NaN           NaN      44.0
# Mewtwo                     NaN               NaN           NaN       NaN
# Palutena                   NaN               NaN           NaN      52.0
# Peach                      NaN               NaN           NaN      49.0
# Pichu                      NaN               NaN           NaN      40.0
# PiranhaPlant               NaN               NaN           NaN      48.0
# Pit                        NaN               NaN           NaN       NaN
# Richter                    NaN               NaN           NaN      43.0
# Ridley                     NaN               NaN           NaN      40.0
# Rob                        NaN               NaN           NaN      48.0
# RosalinaLuma               NaN               NaN           NaN      44.0
# Roy                        NaN               NaN           NaN       NaN
# Ryu                       28.0              38.0          38.0      36.0
# Shulk                      NaN               NaN           NaN      60.0
# Simon                      NaN               NaN           NaN      43.0
# Snake                      NaN               NaN           NaN       NaN
# Squirtle                   NaN               NaN           NaN      42.0
# Terry                      NaN               NaN           NaN       NaN
# Wario                      NaN               NaN           NaN       NaN
# Wolf                       NaN               NaN           NaN      43.0
# YoungLink                  NaN               NaN           NaN      36.0
# Zelda                      NaN               NaN           NaN       NaN
#
# Name          Spotdodge_faf  Standing Grab_faf  Uair_faf  Usmash_faf  \
# Owner
# BanjoKazooie           26.0               37.0       NaN         NaN
# Bowser                 29.0               41.0      45.0        58.0
# Chrom                  26.0               37.0      42.0         NaN
# Daisy                   NaN               37.0       NaN        45.0
# DarkPit                 NaN               35.0       NaN         NaN
# Falco                  26.0               34.0      34.0         NaN
# Fox                     NaN               38.0       NaN        56.0
# Ganondorf               NaN               39.0       NaN        62.0
# Greninja               25.0               39.0       NaN         NaN
# Hero                   26.0               35.0      33.0        54.0
# IceClimbers            26.0               40.0      36.0        50.0
# Ike                     NaN               37.0      57.0        71.0
# Incineroar             27.0               39.0      32.0        48.0
# Inkling                 NaN               35.0       NaN         NaN
# Ivysaur                27.0               43.0      52.0        60.0
# Joker                   NaN               35.0      40.0        52.0
# Ken                    27.0               35.0      36.0        45.0
# KingKRool              29.0               41.0      82.0         NaN
# Kirby                  27.0               34.0      38.0         NaN
# LittleMac              24.0               39.0      42.0        48.0
# Lucina                 26.0               35.0      46.0         NaN
# Marth                  26.0               35.0      46.0         NaN
# MetaKnight             25.0               37.0      27.0         NaN
# Mewtwo                 26.0               40.0      40.0         NaN
# Palutena               26.0               40.0      52.0        64.0
# Peach                   NaN               37.0       NaN        45.0
# Pichu                   NaN               32.0      27.0        41.0
# PiranhaPlant           26.0               35.0      39.0         NaN
# Pit                     NaN               35.0       NaN         NaN
# Richter                 NaN               38.0      40.0        56.0
# Ridley                 29.0               35.0      40.0        48.0
# Rob                    26.0               38.0       NaN         NaN
# RosalinaLuma           27.0               40.0       NaN        48.0
# Roy                     NaN               37.0      42.0         NaN
# Ryu                    27.0               35.0       NaN        45.0
# Shulk                  25.0               37.0       NaN         NaN
# Simon                   NaN               38.0      40.0        56.0
# Snake                   NaN               35.0      48.0         NaN
# Squirtle                NaN               35.0      30.0         NaN
# Terry                  26.0               35.0       NaN        42.0
# Wario                   NaN               36.0      47.0        58.0
# Wolf                    NaN               37.0      39.0         NaN
# YoungLink              25.0               53.0      60.0         NaN
# Zelda                  27.0               40.0      55.0        64.0
#
# Name          Utilt_faf
# Owner
# BanjoKazooie       32.0
# Bowser             41.0
# Chrom              39.0
# Daisy              38.0
# DarkPit             NaN
# Falco               NaN
# Fox                28.0
# Ganondorf           NaN
# Greninja           33.0
# Hero               42.0
# IceClimbers         NaN
# Ike                40.0
# Incineroar         35.0
# Inkling            30.0
# Ivysaur            33.0
# Joker               NaN
# Ken                 NaN
# KingKRool          38.0
# Kirby              21.0
# LittleMac          30.0
# Lucina             34.0
# Marth               NaN
# MetaKnight         35.0
# Mewtwo             30.0
# Palutena           56.0
# Peach              38.0
# Pichu              24.0
# PiranhaPlant       32.0
# Pit                 NaN
# Richter            38.0
# Ridley             30.0
# Rob                 NaN
# RosalinaLuma       41.0
# Roy                 NaN
# Ryu                 NaN
# Shulk              40.0
# Simon              38.0
# Snake              38.0
# Squirtle           20.0
# Terry              31.0
# Wario              28.0
# Wolf               36.0
# YoungLink          32.0
# Zelda              30.0
#
# [44 rows x 45 columns]

# %%
joined_da = damage_pivot.join(angle_pivot, on='Owner', how="outer", lsuffix="_damage", rsuffix="_angle")
print(len(joined_da))
joined_da
# Out:
# 38
# Name          Bair_damage  Bthrow_damage  Dair_damage  Dash Attack_damage  \
# Owner
# BanjoKazooie          NaN           11.4        10.00              12.000
# Bowser             19.000           12.0        16.00              11.000
# Chrom              10.925            5.0        14.25              12.000
# Daisy              12.000            NaN          NaN                 NaN
# DarkPit            12.000            8.0        10.00              11.000
# Falco              13.000            6.0        13.00               9.000
# Fox                13.000            NaN          NaN               6.000
# Ganondorf          17.000            NaN        19.00              15.000
# Greninja              NaN            9.0         8.00               8.000
# Hero               12.000            9.0        16.00              13.000
# IceClimbers        10.000            6.0         8.00               6.000
# Ike                14.000            NaN        15.00              14.000
# Incineroar         11.000            NaN        14.00              13.000
# Ivysaur               NaN           12.0        10.00              12.000
# Joker               9.000           10.0         8.00                 NaN
# Ken                16.000           12.0        15.00              12.000
# KingKRool          14.500           11.0        12.00              15.000
# Kirby              13.000            8.0          NaN               9.000
# LittleMac           6.000            NaN         5.00              10.000
# Lucina             11.875            4.0        14.25              10.925
# Marth               9.000            4.0        15.00              10.000
# MetaKnight            NaN            NaN         6.00               7.000
# Mewtwo             13.000           11.0        15.00              12.000
# Palutena           12.000           10.0        11.00              11.000
# Peach              12.000            NaN          NaN                 NaN
# PiranhaPlant       14.500           11.0        11.00              10.000
# Pit                12.000            8.0        10.00              11.000
# Ridley             15.000           11.0        14.00              12.000
# Rob                15.000           10.0        12.00               7.000
# RosalinaLuma       11.000           11.0         5.75                 NaN
# Ryu                16.000           12.0        15.00              12.000
# Shulk              12.500            NaN          NaN              12.500
# Squirtle            1.000            NaN         1.50               8.000
# Terry              15.000           10.0        17.00              13.000
# Wario              12.000            7.0          NaN              11.000
# Wolf               11.000            NaN        13.00              11.000
# YoungLink             NaN            NaN        18.00              11.000
# Zelda              20.000           12.0        16.00              12.000
#
# Name          Dsmash_damage  Dthrow_damage  Dtilt_damage  Fair_damage  \
# Owner
# BanjoKazooie           15.0            5.6           5.0       15.000
# Bowser                  NaN            NaN           NaN       13.000
# Chrom                   NaN            5.0           9.0        9.025
# Daisy                   NaN            NaN           7.0       14.000
# DarkPit                 NaN            NaN           6.0          NaN
# Falco                  15.0            3.0          13.0        1.000
# Fox                    14.0            NaN           8.0          NaN
# Ganondorf               NaN            7.0          14.0       17.000
# Greninja               13.0            5.0           4.0       14.000
# Hero                    NaN            6.0           7.0       10.000
# IceClimbers            13.0            6.0           6.0       12.000
# Ike                     NaN            NaN           8.0       11.500
# Incineroar             16.0            9.0           9.0       12.000
# Ivysaur                 8.0            7.0           5.5       12.000
# Joker                   NaN            7.0           6.0          NaN
# Ken                    16.0            NaN           NaN       14.000
# KingKRool              18.0            5.0          13.0       12.000
# Kirby                  15.0            NaN           6.0          NaN
# LittleMac               NaN            NaN           8.0        5.000
# Lucina                  NaN            4.0           8.5       10.500
# Marth                   NaN            4.0           7.0        8.000
# MetaKnight              NaN            NaN           5.0          NaN
# Mewtwo                 16.0            NaN           5.0       13.000
# Palutena               15.0            5.0           8.5       10.000
# Peach                   NaN            NaN           7.0       14.000
# PiranhaPlant            NaN            NaN           6.0        9.000
# Pit                     NaN            NaN           6.0          NaN
# Ridley                 16.0            7.0           6.0          NaN
# Rob                     NaN            5.0           5.0        7.000
# RosalinaLuma            NaN            9.0           5.5        1.000
# Ryu                    16.0            NaN           NaN       14.000
# Shulk                   NaN            NaN           9.5        8.000
# Squirtle                NaN            NaN           9.0        7.000
# Terry                  12.0            8.0           3.0       11.000
# Wario                   NaN            NaN           4.0        7.000
# Wolf                    NaN            8.5           6.0        9.000
# YoungLink               NaN            NaN          10.0          NaN
# Zelda                   NaN            NaN           5.5       20.000
#
# Name          Fsmash_damage  Fthrow_damage  ...  Light Utilt_angle  \
# Owner                                       ...
# BanjoKazooie           16.0            NaN  ...                NaN
# Bowser                 23.0           12.0  ...                NaN
# Chrom                  18.0            5.0  ...                NaN
# Daisy                  15.0            NaN  ...                NaN
# DarkPit                 NaN            NaN  ...                NaN
# Falco                  16.0            NaN  ...                NaN
# Fox                    14.0            NaN  ...                NaN
# Ganondorf              24.0            NaN  ...                NaN
# Greninja               14.0            NaN  ...                NaN
# Hero                   18.0            7.0  ...                NaN
# IceClimbers            12.0            NaN  ...                NaN
# Ike                    19.0            NaN  ...                NaN
# Incineroar             16.0           12.0  ...                NaN
# Ivysaur                16.0            NaN  ...                NaN
# Joker                  14.0            8.0  ...                NaN
# Ken                    12.0            9.0  ...               90.0
# KingKRool               NaN           10.0  ...                NaN
# Kirby                   NaN            5.0  ...                NaN
# LittleMac              20.0            NaN  ...                NaN
# Lucina                 15.0            4.0  ...                NaN
# Marth                  13.0            4.0  ...                NaN
# MetaKnight             16.0            NaN  ...                NaN
# Mewtwo                  NaN            NaN  ...                NaN
# Palutena               16.0            9.0  ...                NaN
# Peach                  15.0            NaN  ...                NaN
# PiranhaPlant           15.0            NaN  ...                NaN
# Pit                     NaN            NaN  ...                NaN
# Ridley                 20.0            9.0  ...                NaN
# Rob                     NaN            8.0  ...                NaN
# RosalinaLuma            NaN            9.0  ...                NaN
# Ryu                    16.0            9.0  ...               90.0
# Shulk                   NaN            NaN  ...                NaN
# Squirtle               15.0            NaN  ...                NaN
# Terry                  18.0           10.0  ...                NaN
# Wario                  20.0            NaN  ...                NaN
# Wolf                   15.0            NaN  ...                NaN
# YoungLink               NaN            NaN  ...                NaN
# Zelda                   NaN           10.0  ...                NaN
#
# Name          Medium Dtilt_angle  Medium Jab 1_angle  Medium Utilt_angle  \
# Owner
# BanjoKazooie                 NaN                 NaN                 NaN
# Bowser                       NaN                 NaN                 NaN
# Chrom                        NaN                 NaN                 NaN
# Daisy                        NaN                 NaN                 NaN
# DarkPit                      NaN                 NaN                 NaN
# Falco                        NaN                 NaN                 NaN
# Fox                          NaN                 NaN                 NaN
# Ganondorf                    NaN                 NaN                 NaN
# Greninja                     NaN                 NaN                 NaN
# Hero                         NaN                 NaN                 NaN
# IceClimbers                  NaN                 NaN                 NaN
# Ike                          NaN                 NaN                 NaN
# Incineroar                   NaN                 NaN                 NaN
# Ivysaur                      NaN                 NaN                 NaN
# Joker                        NaN                 NaN                 NaN
# Ken                         64.0                85.0                80.0
# KingKRool                    NaN                 NaN                 NaN
# Kirby                        NaN                 NaN                 NaN
# LittleMac                    NaN                 NaN                 NaN
# Lucina                       NaN                 NaN                 NaN
# Marth                        NaN                 NaN                 NaN
# MetaKnight                   NaN                 NaN                 NaN
# Mewtwo                       NaN                 NaN                 NaN
# Palutena                     NaN                 NaN                 NaN
# Peach                        NaN                 NaN                 NaN
# PiranhaPlant                 NaN                 NaN                 NaN
# Pit                          NaN                 NaN                 NaN
# Ridley                       NaN                 NaN                 NaN
# Rob                          NaN                 NaN                 NaN
# RosalinaLuma                 NaN                 NaN                 NaN
# Ryu                         64.0                85.0                80.0
# Shulk                        NaN                 NaN                 NaN
# Squirtle                     NaN                 NaN                 NaN
# Terry                        NaN                 NaN                 NaN
# Wario                        NaN                 NaN                 NaN
# Wolf                         NaN                 NaN                 NaN
# YoungLink                    NaN                 NaN                 NaN
# Zelda                        NaN                 NaN                 NaN
#
# Name          Nair_angle  Rapid Jab_angle  Uair_angle  Usmash_angle  \
# Owner
# BanjoKazooie         NaN            361.0         NaN         367.0
# Bowser               NaN              NaN        85.0          90.0
# Chrom                NaN              NaN        80.0           NaN
# Daisy              361.0              NaN         NaN          90.0
# DarkPit              NaN            361.0         NaN           NaN
# Falco                NaN            361.0        65.0           NaN
# Fox                361.0              NaN         NaN          80.0
# Ganondorf            NaN              NaN        30.0          85.0
# Greninja            60.0            361.0         NaN           NaN
# Hero                57.0              NaN        73.0          87.0
# IceClimbers        361.0              NaN        70.0          83.0
# Ike                 80.0              NaN        80.0          82.0
# Incineroar         361.0              NaN        85.0          88.0
# Ivysaur            361.0            361.0        90.0          82.0
# Joker               46.0              NaN        80.0          83.0
# Ken                361.0              NaN        75.0          83.0
# KingKRool          361.0              NaN        85.0           NaN
# Kirby               46.0            361.0        70.0          88.0
# LittleMac          367.0            361.0        80.0          86.0
# Lucina               NaN              NaN        85.0          89.0
# Marth                NaN              NaN        80.0          89.0
# MetaKnight         361.0            361.0        67.0           NaN
# Mewtwo               NaN            361.0        72.0           NaN
# Palutena           367.0            361.0       105.0          88.0
# Peach              361.0              NaN         NaN          90.0
# PiranhaPlant       367.0            361.0        85.0           NaN
# Pit                  NaN            361.0         NaN           NaN
# Ridley              44.0            361.0        86.0          82.0
# Rob                 70.0              NaN         NaN          80.0
# RosalinaLuma        60.0            361.0        88.0          86.0
# Ryu                361.0              NaN         NaN          83.0
# Shulk               50.0              NaN         NaN           NaN
# Squirtle            42.0              NaN        64.0          95.0
# Terry               62.0              NaN        75.0          89.0
# Wario                NaN              NaN        88.0          95.0
# Wolf               361.0              NaN        80.0           NaN
# YoungLink          361.0            361.0        80.0           NaN
# Zelda                NaN            361.0        90.0          90.0
#
# Name          Uthrow_angle  Utilt_angle
# Owner
# BanjoKazooie          88.0         86.0
# Bowser                82.0        100.0
# Chrom                 97.0         98.0
# Daisy                 88.0         92.0
# DarkPit               90.0          NaN
# Falco                 94.0          NaN
# Fox                    NaN        110.0
# Ganondorf             90.0        361.0
# Greninja              93.0         92.0
# Hero                  89.0         92.0
# IceClimbers           88.0          NaN
# Ike                   87.0         95.0
# Incineroar            88.0         86.0
# Ivysaur               90.0         88.0
# Joker                 90.0        367.0
# Ken                   88.0          NaN
# KingKRool             90.0         50.0
# Kirby                 78.0        100.0
# LittleMac             85.0         96.0
# Lucina                93.0        100.0
# Marth                 93.0        100.0
# MetaKnight            77.0         95.0
# Mewtwo                90.0        110.0
# Palutena              92.0        367.0
# Peach                 88.0         92.0
# PiranhaPlant          90.0         80.0
# Pit                   90.0          NaN
# Ridley                89.0         88.0
# Rob                   80.0          NaN
# RosalinaLuma          88.0         88.0
# Ryu                   88.0          NaN
# Shulk                 88.0         85.0
# Squirtle               NaN         88.0
# Terry                 80.0         78.0
# Wario                 89.0         92.0
# Wolf                  80.0         80.0
# YoungLink             90.0         85.0
# Zelda                 87.0        100.0
#
# [38 rows x 48 columns]

# %%
joined_ka = knockback_pivot.join(character_attributes_pivot, on='Owner', how="outer", lsuffix="_knockback", rsuffix="_character_attributes")
print(len(joined_ka))
joined_ka
# Out:
# 44
# Name                 Owner  Bair  Bthrow   Dair  Dash Attack  Dsmash  Dthrow  \
# BanjoKazooie  BanjoKazooie   NaN    64.0  20.00         74.0    62.0     NaN
# Bowser              Bowser  20.0    60.0  30.00         95.0     NaN    90.0
# Chrom                Chrom  36.0    70.0  20.00         65.0     NaN    65.0
# Daisy                Daisy  30.0    35.0    NaN          NaN     NaN    60.0
# DarkPit            DarkPit  30.0     NaN   0.00         80.0     NaN    80.0
# Falco                Falco   0.0    70.0  10.00         80.0    20.0    60.0
# Fox                    Fox  20.0     NaN    NaN         55.0    30.0     NaN
# Ganondorf        Ganondorf  40.0    30.0  20.00         50.0     NaN    70.0
# Greninja          Greninja   NaN    55.0  20.00         90.0    32.0    53.0
# Hero                  Hero  32.0    70.0  15.00         70.0     NaN    77.0
# IceClimbers    IceClimbers  25.0    80.0  40.00         90.0    45.0    30.0
# Ike                    Ike  30.0    55.0  30.00         70.0     NaN    75.0
# Incineroar      Incineroar  66.0    57.0  50.00         70.0    75.0    70.0
# Ivysaur            Ivysaur   NaN    60.0  27.00         80.0    40.0    44.0
# Joker                Joker  54.0    70.0  40.00          NaN     NaN    55.0
# Ken                    Ken  21.0    75.0  10.00         80.0    50.0    50.0
# KingKRool        KingKRool  15.0    70.0  10.00         80.0    65.0     NaN
# Kirby                Kirby  15.0    30.0    NaN         80.0    25.0    60.0
# LittleMac        LittleMac  25.0    42.0   0.00         80.0     NaN    50.0
# Lucina              Lucina  40.0    80.0  20.00         75.0     NaN    95.0
# Marth                Marth  40.0    80.0  20.00         70.0     NaN    95.0
# MetaKnight      MetaKnight   NaN    60.0  30.00         65.0     NaN    50.0
# Mewtwo              Mewtwo  20.0    70.0  10.00         80.0    20.0    65.0
# Palutena          Palutena  30.0    65.0  20.00         71.0    40.0    90.0
# Peach                Peach  30.0    35.0    NaN          NaN     NaN    60.0
# PiranhaPlant  PiranhaPlant  23.0    54.0  15.00        100.0     NaN    80.0
# Pit                    Pit  30.0     NaN   0.00         80.0     NaN    80.0
# Ridley              Ridley  35.0    70.0  55.00         70.0    69.0    40.0
# Rob                    Rob  41.0    60.0  10.00         70.0     NaN     NaN
# RosalinaLuma  RosalinaLuma  38.0    70.0  23.75          NaN     NaN    90.0
# Ryu                    Ryu  21.0    75.0  10.00         80.0    50.0    50.0
# Shulk                Shulk  35.0    70.0    NaN         70.0     NaN    85.0
# Squirtle          Squirtle  30.0     NaN    NaN         70.0     NaN     NaN
# Terry                Terry  30.0    60.0  15.00         65.0    36.0    80.0
# Wario                Wario  21.0    80.0    NaN         60.0     NaN    80.0
# Wolf                  Wolf  37.0    40.0   6.00         40.0     NaN    50.0
# YoungLink        YoungLink   NaN    45.0  30.00         70.0     NaN    70.0
# Zelda                Zelda  30.0    40.0  30.00         85.0     NaN    75.0
# NaN                Inkling   NaN     NaN    NaN          NaN     NaN     NaN
# NaN                  Pichu   NaN     NaN    NaN          NaN     NaN     NaN
# NaN                Richter   NaN     NaN    NaN          NaN     NaN     NaN
# NaN                    Roy   NaN     NaN    NaN          NaN     NaN     NaN
# NaN                  Simon   NaN     NaN    NaN          NaN     NaN     NaN
# NaN                  Snake   NaN     NaN    NaN          NaN     NaN     NaN
#
# Name          Dtilt  Fair  Fsmash  ...  Uair  Usmash  Uthrow  Utilt  \
# BanjoKazooie   64.0  36.0    36.0  ...   NaN     NaN    72.0   42.0
# Bowser          NaN  40.0    25.0  ...  35.0    23.0    25.0   55.0
# Chrom          50.0  53.0    60.0  ...  40.0     NaN    60.0   35.0
# Daisy          60.0  50.0    60.0  ...   NaN    24.0    72.0   65.0
# DarkPit        70.0   NaN     NaN  ...   NaN     NaN    70.0    NaN
# Falco          50.0   NaN    42.0  ...  38.0     NaN    60.0    NaN
# Fox            70.0   NaN    28.0  ...   NaN    30.0     NaN   20.0
# Ganondorf      30.0  20.0    61.0  ...  30.0    40.0    70.0   60.0
# Greninja       30.0  30.0    35.0  ...   NaN     NaN    60.0   60.0
# Hero           74.0  36.0    62.0  ...  49.0    60.0    65.0   80.0
# IceClimbers    40.0  40.0    50.0  ...  20.0    50.0   120.0    NaN
# Ike            70.0  55.0    40.0  ...  55.0    50.0    70.0   50.0
# Incineroar     60.0  33.0    65.0  ...  65.0    94.0    68.0   50.0
# Ivysaur        50.0  51.0    45.0  ...  64.0    78.0    75.0   85.0
# Joker          75.0   NaN    40.0  ...  20.0    43.0    70.0   20.0
# Ken             NaN  82.0    26.0  ...  20.0    32.0    55.0    NaN
# KingKRool      40.0  35.0     NaN  ...  56.0     NaN    85.0   50.0
# Kirby          30.0   NaN     NaN  ...  20.0    20.0    75.0   30.0
# LittleMac      50.0  25.0    29.0  ...  25.0    40.0    70.0   25.0
# Lucina         45.0  40.0    65.0  ...  40.0    42.0    70.0   65.0
# Marth          40.0  40.0    48.0  ...  40.0    45.0    70.0   65.0
# MetaKnight     15.0   NaN    30.0  ...  30.0     NaN    70.0   60.0
# Mewtwo         60.0  40.0     NaN  ...  40.0     NaN    72.0   70.0
# Palutena       40.0  31.0    40.0  ...   NaN    53.0    90.0    NaN
# Peach          60.0  50.0    60.0  ...   NaN    24.0    72.0   65.0
# PiranhaPlant   55.0  50.0    25.0  ...  40.0     NaN    64.0   55.0
# Pit            70.0   NaN     NaN  ...   NaN     NaN    70.0    NaN
# Ridley         65.0   NaN    58.0  ...  70.0    58.0    55.0   30.0
# Rob             2.0  30.0     NaN  ...   NaN    40.0    60.0    NaN
# RosalinaLuma   35.0  90.0     NaN  ...  40.0    45.0    50.0   75.0
# Ryu             NaN  82.0    26.0  ...   NaN    32.0    55.0    NaN
# Shulk          45.0  46.0     NaN  ...   NaN     NaN    60.0   70.0
# Squirtle       53.0  50.0    35.0  ...  40.0    60.0     NaN   30.0
# Terry          25.0  45.0    60.0  ...  25.0    32.0    70.0   72.0
# Wario          20.0  30.0    20.0  ...  30.0    35.0    60.0   28.0
# Wolf           25.0  45.0    30.0  ...  30.0     NaN    75.0   30.0
# YoungLink      80.0   NaN     NaN  ...  25.0     NaN    30.0   20.0
# Zelda          15.0  24.0     NaN  ...  55.0     NaN    50.0   45.0
# NaN             NaN   NaN     NaN  ...   NaN     NaN     NaN    NaN
# NaN             NaN   NaN     NaN  ...   NaN     NaN     NaN    NaN
# NaN             NaN   NaN     NaN  ...   NaN     NaN     NaN    NaN
# NaN             NaN   NaN     NaN  ...   NaN     NaN     NaN    NaN
# NaN             NaN   NaN     NaN  ...   NaN     NaN     NaN    NaN
# NaN             NaN   NaN     NaN  ...   NaN     NaN     NaN    NaN
#
# Name          AirAcceleration  AirSpeed  FallSpeed  RunSpeed  WalkSpeed  \
# BanjoKazooie              NaN       NaN        NaN       NaN        NaN
# Bowser                 0.0550    1.1445     1.7100    2.0075     0.9125
# Chrom                  0.0300    1.3020     1.8000    2.2000     1.2080
# Daisy                  0.0800    1.0290     1.1900    1.8260     0.9240
# DarkPit                   NaN       NaN        NaN       NaN        NaN
# Falco                  0.0775    1.0975     1.8325    2.0075     1.1655
# Fox                    0.0800    1.1100     2.1000    2.0900     1.5230
# Ganondorf              0.0300    0.8300     1.6500    1.8700     0.7670
# Greninja               0.0700    1.2390     1.8500    2.1780     1.5020
# Hero                      NaN       NaN        NaN       NaN        NaN
# IceClimbers               NaN       NaN     1.3000    1.6800        NaN
# Ike                    0.0400    1.1340     1.6500    1.8150     0.9120
# Incineroar             0.0600    0.8800     1.7600    1.7600     0.6200
# Ivysaur                0.0850    0.9980     1.3800    1.9030     1.1030
# Joker                     NaN       NaN        NaN       NaN        NaN
# Ken                    0.0250    1.1200     1.6000    1.9360     0.8250
# KingKRool              0.0400    0.9450     1.7000    1.9360     0.9030
# Kirby                  0.0650    0.8400     1.2300    1.9000     0.9770
# LittleMac              0.0300    1.2080     1.9500    2.3650     1.3860
# Lucina                 0.0700    1.0710     1.5800    2.2550     1.5750
# Marth                  0.0700    1.0710     1.5800    2.2550     1.5750
# MetaKnight             0.0650    1.0400     1.6600    2.2110     1.2390
# Mewtwo                 0.0500    1.3130     1.5500    2.2550     1.2600
# Palutena               0.1050    1.0000     1.5500    2.0350     1.2710
# Peach                  0.0800    1.0290     1.1900    1.8260     0.9240
# PiranhaPlant           0.0500    1.0000     1.9500    1.8200     0.7600
# Pit                    0.0650    0.9350     1.4800    2.0900     1.2590
# Ridley                 0.0600    1.0500     1.7800    1.8000     1.1000
# Rob                    0.0700    1.0500     1.5000    1.8150     0.9360
# RosalinaLuma           0.1000    1.0500     1.2000    2.0350     1.1380
# Ryu                    0.0250    1.1200     1.6000    1.7600     0.7500
# Shulk                  0.0400    1.1130     1.5800    1.8700     1.1550
# Squirtle               0.0950    1.0100     1.3500    1.9360     1.2810
# Terry                     NaN       NaN        NaN       NaN        NaN
# Wario                  0.0800    1.2710     1.6100    1.8370     0.8890
# Wolf                   0.0800    1.2810     1.8000    2.0900     1.2080
# YoungLink                 NaN       NaN        NaN       NaN        NaN
# Zelda                  0.0550    1.0920     1.3500    1.9580     0.9140
# NaN                    0.0700    1.2080     1.5800    2.1180     1.1340
# NaN                    0.0900    1.0290     1.9000    1.9800     1.3020
# NaN                    0.0200    0.9400     1.8500    1.7300     0.7600
# NaN                    0.0300    1.3020     1.8000    2.2000     1.2080
# NaN                    0.0200    0.9400     1.8500    1.7300     0.7600
# NaN                    0.0200    0.9870     1.7300    1.7600     0.8820
#
# Name          Weight
# BanjoKazooie     NaN
# Bowser         121.5
# Chrom           95.0
# Daisy           89.0
# DarkPit         96.0
# Falco           93.0
# Fox             77.0
# Ganondorf      118.0
# Greninja        88.0
# Hero             NaN
# IceClimbers     92.0
# Ike            107.0
# Incineroar     116.0
# Ivysaur         96.0
# Joker            NaN
# Ken            103.0
# KingKRool      133.0
# Kirby           79.0
# LittleMac       87.0
# Lucina          90.0
# Marth           90.0
# MetaKnight      80.0
# Mewtwo          77.0
# Palutena        91.0
# Peach           89.0
# PiranhaPlant   112.0
# Pit             96.0
# Ridley         107.0
# Rob             95.0
# RosalinaLuma    82.0
# Ryu            103.0
# Shulk           97.0
# Squirtle        75.0
# Terry            NaN
# Wario          107.0
# Wolf            92.0
# YoungLink        NaN
# Zelda           85.0
# NaN             94.0
# NaN             62.0
# NaN            107.0
# NaN             95.0
# NaN            107.0
# NaN            106.0
#
# [44 rows x 31 columns]
